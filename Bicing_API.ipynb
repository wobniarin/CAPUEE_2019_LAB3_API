# %% [markdown]
# # BICING API

# %%
# import request library (by Python developers)
import requests

# %% [markdown]
# ### Function definition

# %%
""" Method to check if the json contains 'stations' information and return 
a array with all the data """        
def getArrayOfStations(jsonData):
    # Check the elements in the json
    for element in jsonData:
        # If there is an element called 'stations', return the element. 
        # Otherwise, return amb empty array
        if element == 'stations':
            return jsonData[element]
    return []

""" Method to calculate the total number of available bikes """
def totalOfBikes(listOfStations):
    sum = 0
    # For each station, read the element 'bikes' and add it to the total
    for station in listOfStations:
        sum += int(station['bikes'])
    # Return as string the 'sum' variable
    return str(sum)

# %% [markdown]
# ### Main function

# %%
""" Main function of the script, if does the GET petition and checks 
the status code of the HPPT response, if correct, read the json """
if __name__ == "__main__":
    # Request using GET method
    URL = 'http://wservice.viabicing.cat'
    GET = '/v2/stations'
    response = requests.get(url = URL+GET)
    # Read the status code
    status = response.status_code
    # Check the status code
    if status < 200:
        print('informational')
    # If the status code is 200, treat the information.
    elif status >= 200 and status < 300:
        print('ok')
        data = response.json()
        # Use a method to extract from the json the data of the stations
        listOfStations = getArrayOfStations(data)
        # For each station of the list of all the stations, read the Stret name, 
        # number, state and number of bikes
        for station in listOfStations:
            print("station of "+station['streetName']+" "+station['streetNumber']
            + " is "+station['status']+" and has "+station['bikes']+" bikes")
        # Use a method to sum all the total available bikes in all the stations
        print ("the total of bikes is "+totalOfBikes(listOfStations))
    elif status >= 300 and status < 400:
        print('redirection')
    elif status >= 400 and status < 500:
        print('client error')
    else:
        print('server error')
# Out:
# ok
# station of Gran Via Corts Catalanes 760 is CLS and has 0 bikes
# station of Roger de Flor/ Gran Vía 126 is CLS and has 0 bikes
# station of Nàpols 82 is CLS and has 0 bikes
# station of Ribes 13 is CLS and has 0 bikes
# station of Pg Lluís Companys 11 is CLS and has 0 bikes
# station of Pg Lluís Companys 18 is CLS and has 0 bikes
# station of Pg Lluís Companys 1 is CLS and has 0 bikes
# station of Pg Lluís Companys 2 is CLS and has 0 bikes
# station of Marquès de l'Argentera 13 is CLS and has 0 bikes
# station of Carrer Comerç 27 is CLS and has 0 bikes
# station of Passeig Marítim 19 is CLS and has 0 bikes
# station of Pg Marítim Barceloneta 23 is CLS and has 0 bikes
# station of Avinguda Litoral 16 is CLS and has 0 bikes
# station of Avinguda del Marques Argentera 15 is CLS and has 0 bikes
# station of Girona 68 is CLS and has 0 bikes
# station of Av. Meridiana 47 is CLS and has 0 bikes
# station of Rosselló 453 is CLS and has 0 bikes
# station of Rosselló 354 is CLS and has 0 bikes
# station of Cartagena 308 is CLS and has 0 bikes
# station of Sant Antoni Maria Claret 214 is CLS and has 0 bikes
# station of Sardenya 292 is CLS and has 0 bikes
# station of Bruc 45 is CLS and has 0 bikes
# station of Marina 199 is CLS and has 0 bikes
# station of Bruc 102 is CLS and has 0 bikes
# station of Dos Maig 230 is CLS and has 0 bikes
# station of Provença 322 is CLS and has 0 bikes
# station of Sardenya 362 is CLS and has 0 bikes
# station of Provença 388 is CLS and has 0 bikes
# station of Diagonal 231 is CLS and has 0 bikes
# station of Plaça del Mar 72 is CLS and has 0 bikes
# station of Plaça del Mar 1 is CLS and has 1 bikes
# station of Pontevedra  58B is CLS and has 0 bikes
# station of Sant Pere Més Alt 4 is CLS and has 0 bikes
# station of Sant Ramon de Penyafort 1 is CLS and has 0 bikes
# station of Catedral 6 is CLS and has 0 bikes
# station of Pl. Antonio López  is CLS and has 0 bikes
# station of Pl. Pau Vila  is CLS and has 0 bikes
# station of Doctor Aiguader 2 is CLS and has 0 bikes
# station of Pl. Poeta Boscà/Atlàntida  is CLS and has 0 bikes
# station of Ciutat de Granada 168 is CLS and has 0 bikes
# station of Av Meridiana 80 is CLS and has 0 bikes
# station of Av Meridiana 66 is CLS and has 0 bikes
# station of Sardenya 66 is CLS and has 0 bikes
# station of Ramon trias Fargas 19 is CLS and has 0 bikes
# station of Ramon Trias Fargas 23 is CLS and has 0 bikes
# station of Meridiana 40 is CLS and has 0 bikes
# station of Rosa Sensat en front 20 is CLS and has 0 bikes
# station of Av. Paral.lel 54 is CLS and has 0 bikes
# station of Pl. Vicenç Martorell  is CLS and has 0 bikes
# station of Plaça de Sant Miquel 1 is CLS and has 0 bikes
# station of Pl. Carles Pi i Sunyer  is CLS and has 0 bikes
# station of Sant Oleguer 2 is CLS and has 0 bikes
# station of La Rambla 80 is CLS and has 0 bikes
# station of Portal de Santa Madrona 2 is CLS and has 0 bikes
# station of La Rambla 2 is CLS and has 0 bikes
# station of Plaça dels Àngels 1 is CLS and has 1 bikes
# station of Plaça dels Àngels 2 is CLS and has 0 bikes
# station of Rambla Catalunya  47 is CLS and has 0 bikes
# station of Rambla Catalunya 42 is CLS and has 0 bikes
# station of Pl. Catalunya  5 is CLS and has 0 bikes
# station of Pl. Catalunya 7 is CLS and has 0 bikes
# station of Pl. Catalunya  is CLS and has 1 bikes
# station of Pl. Catalunya  is CLS and has 0 bikes
# station of Gran Via 609 is CLS and has 0 bikes
# station of Rocafort 214 is CLS and has 0 bikes
# station of Rambla Catalunya 133 is CLS and has 0 bikes
# station of Avda. Litoral  is CLS and has 0 bikes
# station of Comte Urgell 23 is CLS and has 0 bikes
# station of Floridablanca 145 is CLS and has 0 bikes
# station of Provença 215 is CLS and has 0 bikes
# station of Enric Granados 93 is CLS and has 0 bikes
# station of Josep Tarradellas 133 is CLS and has 0 bikes
# station of Josep Tarradellas 58 is CLS and has 0 bikes
# station of Còrsega 216 is CLS and has 0 bikes
# station of Casanova 141 is CLS and has 0 bikes
# station of Pl. Universitat  is CLS and has 0 bikes
# station of Pl. Universitat  is CLS and has 0 bikes
# station of Enric Granados 35 is CLS and has 0 bikes
# station of Vilamarí davant 61 is CLS and has 0 bikes
# station of Rocafort 72 is CLS and has 0 bikes
# station of Comte Borrell 177 is CLS and has 0 bikes
# station of Comte d'Urgell 75 B is CLS and has 0 bikes
# station of Paral·lel 146 is CLS and has 6 bikes
# station of Viladomat 2 is CLS and has 0 bikes
# station of Mallorca 41 is CLS and has 0 bikes
# station of Londres 101 is CLS and has 0 bikes
# station of Rosselló 101 is CLS and has 0 bikes
# station of Rosselló 108 is CLS and has 0 bikes
# station of Comte Borrell 119 is CLS and has 0 bikes
# station of Provença 241 is CLS and has 0 bikes
# station of Gran Via 375 is CLS and has 0 bikes
# station of Gran Via 375 is CLS and has 0 bikes
# station of Tarragona 103 is CLS and has 0 bikes
# station of Gran Via 361 is CLS and has 0 bikes
# station of Tarragona 141 is CLS and has 2 bikes
# station of Viriat 45 is CLS and has 0 bikes
# station of Viriat 53 is CLS and has 0 bikes
# station of Tarragona 159 is CLS and has 0 bikes
# station of Av. Diagonal 602 is CLS and has 0 bikes
# station of Av. Diagonal 612 is CLS and has 0 bikes
# station of Aragó 629 is CLS and has 0 bikes
# station of C/València 621 is CLS and has 0 bikes
# station of PL. Urquinaona 9 is CLS and has 0 bikes
# station of Pl. Joanic s/n is CLS and has 0 bikes
# station of Travessera de Gracia 92 is CLS and has 0 bikes
# station of Indústria 10 is CLS and has 0 bikes
# station of C/ Londres 53 is CLS and has 0 bikes
# station of Avda. Roma 136 is CLS and has 0 bikes
# station of Calabria 137 is CLS and has 0 bikes
# station of Floridablanca 49 is CLS and has 0 bikes
# station of Sant Pau 51 is CLS and has 2 bikes
# station of Pl. Jean Genet 1 is CLS and has 0 bikes
# station of Marqués d'Argentera 3 is CLS and has 3 bikes
# station of Salvat Papasseit 72 is CLS and has 0 bikes
# station of Rosa Sensat 12 is CLS and has 0 bikes
# station of Sardenya 3 is CLS and has 0 bikes
# station of Sardenya 178 is CLS and has 0 bikes
# station of Lepant 278 is CLS and has 0 bikes
# station of Castillejos 258 is CLS and has 0 bikes
# station of Nàpols 344 is CLS and has 0 bikes
# station of Girona 142 is CLS and has 0 bikes
# station of Passeig Joan de Borbó s/n is CLS and has 0 bikes
# station of Passeig Maritim 31 is CLS and has 0 bikes
# station of Passeig de Colom  is CLS and has 0 bikes
# station of Aragó 661 is CLS and has 0 bikes
# station of Rambla Guipúscoa 43 is CLS and has 0 bikes
# station of Manso 46 is CLS and has 7 bikes
# station of Rambla Guipúscoa 103 is CLS and has 0 bikes
# station of Rambla Guipúscoa 158 is CLS and has 0 bikes
# station of Pl. Valentí Amirall  is CLS and has 0 bikes
# station of Gran Vía 902 is CLS and has 0 bikes
# station of Bac de Roda 157 is CLS and has 0 bikes
# station of Gran Vía 981 is CLS and has 0 bikes
# station of Gran Vía 1062 is CLS and has 22 bikes
# station of Gran Vía, 1041/ Selva de Mar 1041 is CLS and has 0 bikes
# station of Gran Vía 1118 is CLS and has 0 bikes
# station of Gran Vía 1131 is CLS and has 26 bikes
# station of Viladomat 122 is CLS and has 0 bikes
# station of Gran Via  940 is CLS and has 0 bikes
# station of Sancho de Ávila 104 is CLS and has 0 bikes
# station of Sancho de Ávila 170 is CLS and has 0 bikes
# station of Castella 28 is CLS and has 0 bikes
# station of Pere IV 301 is CLS and has 0 bikes
# station of Pere IV 449 is CLS and has 0 bikes
# station of Rambla Prim 79 is CLS and has 0 bikes
# station of Ronda Sant Pau 79 is CLS and has 0 bikes
# station of Pujades 57B is CLS and has 0 bikes
# station of Espronceda 124 is CLS and has 0 bikes
# station of Pallars 462 is CLS and has 0 bikes
# station of Pujades 121 is CLS and has 0 bikes
# station of Pujades 173 is CLS and has 0 bikes
# station of Pujades 191 is CLS and has 0 bikes
# station of Pujades 311 is CLS and has 0 bikes
# station of Diagonal 46 is CLS and has 0 bikes
# station of C/ LLULL - RBLA. PRIM 465 is CLS and has 0 bikes
# station of Rambla de Prim 19 is CLS and has 0 bikes
# station of Avda. Diagonal 26 is CLS and has 0 bikes
# station of Avda. d'Eduard Maristany 1 is CLS and has 0 bikes
# station of Ramon Turro 91 is CLS and has 0 bikes
# station of Ramon Turro 292 is CLS and has 0 bikes
# station of Avda. Icaria 202 is CLS and has 0 bikes
# station of Independència 379 is CLS and has 0 bikes
# station of Carrer del Doctor Trueta 221 is CLS and has 0 bikes
# station of Bilbao 11 is CLS and has 0 bikes
# station of Bac de Roda 11 is CLS and has 0 bikes
# station of Selva de Mar 0 is CLS and has 0 bikes
# station of Avda. Litoral 40 is CLS and has 0 bikes
# station of Passeig Marítim de la Nova Icària 83 is CLS and has 0 bikes
# station of Avda. Litoral 84 is CLS and has 0 bikes
# station of Passeig de Garcia Fària 21 is CLS and has 1 bikes
# station of Llull / Provençals 309 is CLS and has 0 bikes
# station of Passeig de Garcia Fària 37 is CLS and has 0 bikes
# station of Rosselló 557 is CLS and has 0 bikes
# station of Passeig de Garcia Fària 85 is CLS and has 0 bikes
# station of Pg. Zona Franca 244 is CLS and has 0 bikes
# station of Gran Via 181 is CLS and has 0 bikes
# station of Gran Via 180 is CLS and has 0 bikes
# station of Gran Via 273 is CLS and has 0 bikes
# station of Gavà 1 is CLS and has 0 bikes
# station of Quetzal 22 is CLS and has 0 bikes
# station of Gavà 81 is CLS and has 0 bikes
# station of Consell de Cent 6 is CLS and has 0 bikes
# station of Carrer de Sant Pau 89 is CLS and has 0 bikes
# station of Pl. Sants (Ps. S. Antoni) 0 is CLS and has 0 bikes
# station of Bruc 130 is CLS and has 0 bikes
# station of Avinguda Litoral 72 is CLS and has 0 bikes
# station of Rocafort 167 is CLS and has 0 bikes
# station of Joan Güell 50 is CLS and has 2 bikes
# station of Figols 1 is CLS and has 0 bikes
# station of Joan Güell 98 is CLS and has 0 bikes
# station of Vallespir 130 is CLS and has 0 bikes
# station of Berlín 38 is CLS and has 0 bikes
# station of Gelabert 1 is CLS and has 0 bikes
# station of Vallespir 194 is CLS and has 0 bikes
# station of Mejía Lequerica 2 is CLS and has 0 bikes
# station of Can bruixa 1 is CLS and has 0 bikes
# station of Numància 136 is CLS and has 21 bikes
# station of Carrer de les Corts 20 is CLS and has 0 bikes
# station of Avda. Diagonal 664 is CLS and has 0 bikes
# station of Avda. Diagonal 668 is CLS and has 0 bikes
# station of Europa  25 is CLS and has 0 bikes
# station of Avda. Diagonal 650 is CLS and has 0 bikes
# station of Avda. Diagonal 634 is CLS and has 0 bikes
# station of Avda. Diagonal 630 is CLS and has 0 bikes
# station of Diputació 200 is CLS and has 0 bikes
# station of Vilardell 18 is CLS and has 11 bikes
# station of Sancho de Ávila 60 is CLS and has 0 bikes
# station of Av. Sarrià 163 is CLS and has 25 bikes
# station of Sant Fe de Nou Mèxic 2 is CLS and has 0 bikes
# station of José de Agulló 19 is CLS and has 16 bikes
# station of Carrer de Ganduxer 29 is CLS and has 20 bikes
# station of Madrazo 131 is CLS and has 0 bikes
# station of Rector Ubach 24 is CLS and has 2 bikes
# station of Consell de Cent 566 is CLS and has 0 bikes
# station of Carre Laforja 74 is CLS and has 0 bikes
# station of Tuset 19 is CLS and has 0 bikes
# station of Gran de Gràcia 155 is CLS and has 0 bikes
# station of Carrer del Canó 1 is CLS and has 0 bikes
# station of Carrer de Bonavista 14 is CLS and has 0 bikes
# station of Girona 176 is CLS and has 0 bikes
# station of Mallorca 84 is CLS and has 0 bikes
# station of Montmany 1 is CLS and has 0 bikes
# station of Torrent de Les Flors 102 is CLS and has 0 bikes
# station of Pl. Del Nord 5 is CLS and has 0 bikes
# station of Carrer de la Santacreu 2 is CLS and has 0 bikes
# station of C. De Nil Fabra 16 is CLS and has 7 bikes
# station of Pi i Margall 38 is CLS and has 2 bikes
# station of Vilà i Vilà 45 is CLS and has 0 bikes
# station of Nou de la Rambla 164 is CLS and has 0 bikes
# station of Passeig de l'Exposició 30 is CLS and has 1 bikes
# station of Paral.lel 98 is CLS and has 0 bikes
# station of Avinguda Paral.lel 194 is CLS and has 0 bikes
# station of Rius i Taulet 4 is CLS and has 0 bikes
# station of Espronceda 298 is CLS and has 0 bikes
# station of Indústria 329 is CLS and has 0 bikes
# station of Josep Estivill 32 is CLS and has 0 bikes
# station of Teodor Llorente 2 is CLS and has 0 bikes
# station of Ramon Albó 1 is CLS and has 0 bikes
# station of Alenxadre Galí 1 is CLS and has 0 bikes
# station of Felip II 214 is CLS and has 0 bikes
# station of Garcilaso 77 is CLS and has 0 bikes
# station of Felipe II 112 is CLS and has 0 bikes
# station of Palència 31 is CLS and has 0 bikes
# station of Açores 1 is CLS and has 0 bikes
# station of Portugal 3 is CLS and has 0 bikes
# station of Cardenal Tedeschini 13 is CLS and has 0 bikes
# station of Rambla Onze de Setembre 31 is CLS and has 0 bikes
# station of Onze de Setembre 37 is CLS and has 0 bikes
# station of Gran de Sant Andreu 69 is CLS and has 0 bikes
# station of Irlanda 11 is CLS and has 0 bikes
# station of Malats 28 is CLS and has 0 bikes
# station of Sant Adrià 2 is CLS and has 0 bikes
# station of Fernando Pessoa 41 is CLS and has 0 bikes
# station of Carrer de Bartrina 14 is CLS and has 0 bikes
# station of Plaça de l'Estació 6 is CLS and has 0 bikes
# station of Villarroel 39 is CLS and has 0 bikes
# station of Rocafort 103 is CLS and has 15 bikes
# station of Pg.Torras i Bages 29 is CLS and has 0 bikes
# station of República Dominicana 25 is CLS and has 0 bikes
# station of Casanovas 67 is CLS and has 9 bikes
# station of Concepció Arenal 176 is CLS and has 0 bikes
# station of Passeig Torras i Bages 129 is CLS and has 1 bikes
# station of Fernando Pessoa 72 is CLS and has 0 bikes
# station of Via Barcino 121 is CLS and has 0 bikes
# station of Crta. de Ribes (Trinitat Vella) 77 is CLS and has 0 bikes
# station of Via Barcino 69 is CLS and has 0 bikes
# station of Concepció Arenal 281 is CLS and has 0 bikes
# station of Avda. Meridiana 404 is CLS and has 0 bikes
# station of Rambla Fabra i Puig 67 is CLS and has 0 bikes
# station of Rio de Janeiro 3 is CLS and has 0 bikes
# station of Plaça Alfons X el Savi / Ronda del Guinardó   is CLS and has 1 bikes
# station of Travessera de Gràcia 328 is CLS and has 0 bikes
# station of Travessera de Gràcia 368 is CLS and has 0 bikes
# station of Mas Casanovas 137 is CLS and has 0 bikes
# station of Sant Antoni Mª Claret 290 is CLS and has 0 bikes
# station of Escornalbou 51 is CLS and has 0 bikes
# station of Font d'en Fargas 1 is CLS and has 0 bikes
# station of Carrer Fulton 1 is CLS and has 0 bikes
# station of Ada. Diagonal 652 is CLS and has 0 bikes
# station of Malats 98 is CLS and has 0 bikes
# station of Bolívia 76 is CLS and has 0 bikes
# station of Gran Via 632 is CLS and has 0 bikes
# station of Pl. Virrei Amat  is CLS and has 0 bikes
# station of Múrcia 64 is CLS and has 0 bikes
# station of Plaça dels Jardins d'Alfàbia 1 is CLS and has 0 bikes
# station of Cubelles 2 is CLS and has 0 bikes
# station of Amilcar 1 is CLS and has 0 bikes
# station of Granollers 1 is CLS and has 0 bikes
# station of Seu del Districte (Nou Barris)  is CLS and has 0 bikes
# station of Sant Iscle 60 is CLS and has 0 bikes
# station of Carrer de Rosselló i Porcel 1 is CLS and has 12 bikes
# station of Carrer Turó Blau 1 is CLS and has 0 bikes
# station of Andreu Nin 22 is CLS and has 0 bikes
# station of Carrer de l'Escultor Ordóñez 55 is CLS and has 0 bikes
# station of Carrer de Maladeta 1 is CLS and has 0 bikes
# station of Marie Curie 8 is CLS and has 0 bikes
# station of Cavallers 41 is CLS and has 0 bikes
# station of Cavallers 67 is CLS and has 0 bikes
# station of Manuel Girona 7 is CLS and has 0 bikes
# station of Diagonal 680 is CLS and has 0 bikes
# station of Doctor Salvador Cardenal 7 is CLS and has 2 bikes
# station of Pintor Ribalta  is CLS and has 0 bikes
# station of Cardenal Reig 11 is CLS and has 0 bikes
# station of Sant Ramón Nonat 26 is CLS and has 15 bikes
# station of Josep Samitier  is CLS and has 0 bikes
# station of Gallego-Arístides Maillol 2 is CLS and has 0 bikes
# station of Arizala 77 is CLS and has 32 bikes
# station of Feliu de Casanova 1 is CLS and has 0 bikes
# station of Rambla del Brasil 44 is CLS and has 0 bikes
# station of Guinardó 32 is CLS and has 0 bikes
# station of Cantàbria 55 is CLS and has 1 bikes
# station of Rambla Prim 256 is CLS and has 0 bikes
# station of Cartagena 83 is CLS and has 0 bikes
# station of Saguès 1 is CLS and has 16 bikes
# station of Vía Augusta 21 is CLS and has 9 bikes
# station of Carrer de Sant Hermenegild 30 is CLS and has 0 bikes
# station of Santaló 165 is CLS and has 0 bikes
# station of Vallmajor 13 is CLS and has 0 bikes
# station of Reina Victoria 31 is CLS and has 0 bikes
# station of Alt de Gironella 13 is CLS and has 0 bikes
# station of Balmes 409 is CLS and has 0 bikes
# station of Reus 23 is CLS and has 0 bikes
# station of Artesa de Segre 2 is CLS and has 0 bikes
# station of Carrer de les Escoles Pies 99 is CLS and has 0 bikes
# station of Doctor Carulla 44 is CLS and has 0 bikes
# station of Castellnou 65 is CLS and has 0 bikes
# station of Doctor Roux 86 is CLS and has 0 bikes
# station of Passatge de Senillosa 3 is CLS and has 0 bikes
# station of Via Augusta 348 is CLS and has 0 bikes
# station of Santa Amèlia 2 is CLS and has 0 bikes
# station of Caponata 10 is CLS and has 0 bikes
# station of Carme Karr 12 is CLS and has 0 bikes
# station of Avinguda de J.Foix 63 is CLS and has 0 bikes
# station of Ramon Turró 246 is CLS and has 0 bikes
# station of Sant Adrià 113 is CLS and has 0 bikes
# station of Pl. Mossèn Joan Cortines . is CLS and has 0 bikes
# station of Roc Boronat 134 is CLS and has 0 bikes
# station of Campana de la Maquinista  is CLS and has 0 bikes
# station of Ciutat d'Asunción 73 is CLS and has 0 bikes
# station of Pl. Teresa de Claramunt  is CLS and has 1 bikes
# station of Carrer de la Foneria 33 is CLS and has 0 bikes
# station of Alts Forns 77 is CLS and has 0 bikes
# station of Jardins de Can Ferrero  is CLS and has 0 bikes
# station of Carrer de l'Energia 2 is CLS and has 0 bikes
# station of Villarroel 208 is CLS and has 0 bikes
# station of Jane Addams 26 is CLS and has 0 bikes
# station of Radi 10 is CLS and has 0 bikes
# station of Munné 6 is CLS and has 0 bikes
# station of Rambla del Brasil 5 is CLS and has 0 bikes
# station of Carreras i Candi 89 is CLS and has 0 bikes
# station of Camèlies 73 is CLS and has 0 bikes
# station of Cardener 82 is CLS and has 0 bikes
# station of Gombau 24 is CLS and has 0 bikes
# station of Méndez Núñez 16 is CLS and has 0 bikes
# station of Bailén 62 is CLS and has 0 bikes
# station of Passeig de Colom  is CLS and has 0 bikes
# station of Bailén 100 is CLS and has 0 bikes
# station of Bruc 20 is CLS and has 0 bikes
# station of Passeig de Gràcia 61 is CLS and has 0 bikes
# station of Viladomat 244 is CLS and has 0 bikes
# station of Pau Casals 1 is CLS and has 0 bikes
# station of Sentmenat 39 is CLS and has 1 bikes
# station of Diputació 350 is CLS and has 0 bikes
# station of Consell de Cent 482 is CLS and has 0 bikes
# station of Sardenya 234 is CLS and has 0 bikes
# station of Carrer dels Enamorats 49 is CLS and has 0 bikes
# station of Ribes 77 is CLS and has 0 bikes
# station of Av. Paral.lel 132 is CLS and has 0 bikes
# station of Passeig de Gràcia 89 is CLS and has 0 bikes
# station of World Trade Center  is CLS and has 0 bikes
# station of World Trade Center  is CLS and has 0 bikes
# station of Pl. Ictíneo  is CLS and has 0 bikes
# station of Pl.Joaquim Xira i Palau 1 is CLS and has 0 bikes
# station of Pl. Sant Miquel 4 is CLS and has 0 bikes
# station of Duran i Bas 2 is CLS and has 0 bikes
# station of Agustí Duran i Sanpere 10 is CLS and has 0 bikes
# station of Lope de Vega 79 is CLS and has 0 bikes
# station of Vilamarí 85 is CLS and has 0 bikes
# station of Casanova 119 is CLS and has 0 bikes
# station of Av.Paral.lel 164 is CLS and has 0 bikes
# station of Nàpols 125 is CLS and has 0 bikes
# station of Riera Alta 6 is CLS and has 0 bikes
# station of Recinte Parc de la Ciutadella  is CLS and has 0 bikes
# station of Comerç 36 is CLS and has 0 bikes
# station of Sagrera 74 is CLS and has 0 bikes
# station of Ramon Turró 4 is CLS and has 0 bikes
# station of Llacuna 86 is CLS and has 0 bikes
# station of Diputació 226 is CLS and has 0 bikes
# station of Pl. Catalunya 22 is CLS and has 0 bikes
# station of Joan Miró 2 is CLS and has 0 bikes
# station of Av. Del Litoral 24 is CLS and has 0 bikes
# station of Passeig Marítim de la Barceloneta  is CLS and has 0 bikes
# station of Moll Oriental  is CLS and has 0 bikes
# station of Pl. Antonio López (Via Laietana) annexa a la 37  is CLS and has 0 bikes
# station of Passeig de Colom  is CLS and has 0 bikes
# station of Juan Gris 28 is CLS and has 0 bikes
# station of Comte Borrell 198 is CLS and has 0 bikes
# station of Gran Via de Les Corts Catalanes 592 is CLS and has 0 bikes
# station of Ramon Trias Fargas 23 is CLS and has 0 bikes
# station of Joan d'Àustria 31 B is CLS and has 0 bikes
# station of Passeig de Colom, s/n  is CLS and has 0 bikes
# station of Rambla Catalunya (Diputació) 31 is CLS and has 0 bikes
# station of Pl. Urquinaona 3 is CLS and has 0 bikes
# station of Bruc 66 is CLS and has 2 bikes
# station of Casp 67 is CLS and has 0 bikes
# station of Rambla del Raval 13 is CLS and has 0 bikes
# station of Rambla del Raval 20 is CLS and has 0 bikes
# station of Passeig de Lluís Companys   is CLS and has 1 bikes
# station of Passeig de Lluís Companys  is CLS and has 0 bikes
# station of Gran Via 361 is CLS and has 6 bikes
# station of Plaça de Joan Peiró  is CLS and has 0 bikes
# station of Carrer d'Hondures 32 is CLS and has 23 bikes
# station of Passeig Marítim de la Barceloneta, devant del 5-7 5 is CLS and has 0 bikes
# station of Carrer de Cervelló 5 is CLS and has 0 bikes
# station of Carrer de Ribes 59 is CLS and has 0 bikes
# station of Carrer de Sant Pau 119 is CLS and has 0 bikes
# station of Carrer Pujades 103 is CLS and has 0 bikes
# the total of bikes is 326

# %%
status
# Out:
# 200

# %%
data
# Out:
# {'stations': [{'id': '1',
#    'type': 'BIKE',
#    'latitude': '41.397952',
#    'longitude': '2.180042',
#    'streetName': 'Gran Via Corts Catalanes',
#    'streetNumber': '760',
#    'altitude': '21',
#    'slots': '29',
#    'bikes': '0',
#    'nearbyStations': '1',
#    'status': 'CLS'},
#   {'id': '2',
#    'type': 'BIKE',
#    'latitude': '41.39553',
#    'longitude': '2.17706',
#    'streetName': 'Roger de Flor/ Gran Vía',
#    'streetNumber': '126',
#    'altitude': '21',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '2',
#    'status': 'CLS'},
#   {'id': '3',
#    'type': 'BIKE',
#    'latitude': '41.394055',
#    'longitude': '2.181299',
#    'streetName': 'Nàpols',
#    'streetNumber': '82',
#    'altitude': '22',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '3',
#    'status': 'CLS'},
#   {'id': '4',
#    'type': 'BIKE',
#    'latitude': '41.39348',
#    'longitude': '2.181555',
#    'streetName': 'Ribes',
#    'streetNumber': '13',
#    'altitude': '21',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '4',
#    'status': 'CLS'},
#   {'id': '5',
#    'type': 'BIKE',
#    'latitude': '41.391075',
#    'longitude': '2.180223',
#    'streetName': 'Pg Lluís Companys',
#    'streetNumber': '11',
#    'altitude': '16',
#    'slots': '39',
#    'bikes': '0',
#    'nearbyStations': '5',
#    'status': 'CLS'},
#   {'id': '6',
#    'type': 'BIKE',
#    'latitude': '41.391349',
#    'longitude': '2.18061',
#    'streetName': 'Pg Lluís Companys',
#    'streetNumber': '18',
#    'altitude': '16',
#    'slots': '39',
#    'bikes': '0',
#    'nearbyStations': '6',
#    'status': 'CLS'},
#   {'id': '7',
#    'type': 'BIKE',
#    'latitude': '41.388856',
#    'longitude': '2.183251',
#    'streetName': 'Pg Lluís Companys',
#    'streetNumber': '1',
#    'altitude': '16',
#    'slots': '23',
#    'bikes': '0',
#    'nearbyStations': '7',
#    'status': 'CLS'},
#   {'id': '8',
#    'type': 'BIKE',
#    'latitude': '41.389088',
#    'longitude': '2.183568',
#    'streetName': 'Pg Lluís Companys',
#    'streetNumber': '2',
#    'altitude': '11',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '8',
#    'status': 'CLS'},
#   {'id': '9',
#    'type': 'BIKE',
#    'latitude': '41.384532',
#    'longitude': '2.184921',
#    'streetName': "Marquès de l'Argentera",
#    'streetNumber': '13',
#    'altitude': '11',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '9',
#    'status': 'CLS'},
#   {'id': '10',
#    'type': 'BIKE',
#    'latitude': '41.38498',
#    'longitude': '2.18417',
#    'streetName': 'Carrer Comerç',
#    'streetNumber': '27',
#    'altitude': '11',
#    'slots': '0',
#    'bikes': '0',
#    'nearbyStations': '10',
#    'status': 'CLS'},
#   {'id': '11',
#    'type': 'BIKE',
#    'latitude': '41.381689',
#    'longitude': '2.193914',
#    'streetName': 'Passeig Marítim',
#    'streetNumber': '19',
#    'altitude': '1',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '11',
#    'status': 'CLS'},
#   {'id': '12',
#    'type': 'BIKE',
#    'latitude': '41.384538',
#    'longitude': '2.195679',
#    'streetName': 'Pg Marítim Barceloneta',
#    'streetNumber': '23',
#    'altitude': '0',
#    'slots': '29',
#    'bikes': '0',
#    'nearbyStations': '12',
#    'status': 'CLS'},
#   {'id': '13',
#    'type': 'BIKE',
#    'latitude': '41.386861',
#    'longitude': '2.195761',
#    'streetName': 'Avinguda Litoral',
#    'streetNumber': '16',
#    'altitude': '1',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '13',
#    'status': 'CLS'},
#   {'id': '14',
#    'type': 'BIKE',
#    'latitude': '41.384675',
#    'longitude': '2.185039',
#    'streetName': 'Avinguda del Marques Argentera',
#    'streetNumber': '15',
#    'altitude': '11',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '14',
#    'status': 'CLS'},
#   {'id': '15',
#    'type': 'BIKE',
#    'latitude': '41.394812',
#    'longitude': '2.171189',
#    'streetName': 'Girona',
#    'streetNumber': '68',
#    'altitude': '40',
#    'slots': '18',
#    'bikes': '0',
#    'nearbyStations': '15',
#    'status': 'CLS'},
#   {'id': '17',
#    'type': 'BIKE',
#    'latitude': '41.398237',
#    'longitude': '2.186711',
#    'streetName': 'Av. Meridiana',
#    'streetNumber': '47',
#    'altitude': '18',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '17',
#    'status': 'CLS'},
#   {'id': '18',
#    'type': 'BIKE',
#    'latitude': '41.406086',
#    'longitude': '2.174167',
#    'streetName': 'Rosselló',
#    'streetNumber': '453',
#    'altitude': '49',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '18',
#    'status': 'CLS'},
#   {'id': '19',
#    'type': 'BIKE',
#    'latitude': '41.403282',
#    'longitude': '2.170726',
#    'streetName': 'Rosselló',
#    'streetNumber': '354',
#    'altitude': '49',
#    'slots': '28',
#    'bikes': '0',
#    'nearbyStations': '19',
#    'status': 'CLS'},
#   {'id': '20',
#    'type': 'BIKE',
#    'latitude': '41.410166',
#    'longitude': '2.175759',
#    'streetName': 'Cartagena',
#    'streetNumber': '308',
#    'altitude': '59',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '20',
#    'status': 'CLS'},
#   {'id': '21',
#    'type': 'BIKE',
#    'latitude': '41.410897',
#    'longitude': '2.17402',
#    'streetName': 'Sant Antoni Maria Claret',
#    'streetNumber': '214',
#    'altitude': '59',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '21',
#    'status': 'CLS'},
#   {'id': '22',
#    'type': 'BIKE',
#    'latitude': '41.401684',
#    'longitude': '2.17568',
#    'streetName': 'Sardenya',
#    'streetNumber': '292',
#    'altitude': '28',
#    'slots': '19',
#    'bikes': '0',
#    'nearbyStations': '22',
#    'status': 'CLS'},
#   {'id': '23',
#    'type': 'BIKE',
#    'latitude': '41.392526',
#    'longitude': '2.171812',
#    'streetName': 'Bruc',
#    'streetNumber': '45',
#    'altitude': '42',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '23',
#    'status': 'CLS'},
#   {'id': '24',
#    'type': 'BIKE',
#    'latitude': '41.400659',
#    'longitude': '2.179111',
#    'streetName': 'Marina',
#    'streetNumber': '199',
#    'altitude': '30',
#    'slots': '30',
#    'bikes': '0',
#    'nearbyStations': '24',
#    'status': 'CLS'},
#   {'id': '25',
#    'type': 'BIKE',
#    'latitude': '41.395179',
#    'longitude': '2.168294',
#    'streetName': 'Bruc',
#    'streetNumber': '102',
#    'altitude': '42',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '25',
#    'status': 'CLS'},
#   {'id': '26',
#    'type': 'BIKE',
#    'latitude': '41.407035',
#    'longitude': '2.181981',
#    'streetName': 'Dos Maig',
#    'streetNumber': '230',
#    'altitude': '28',
#    'slots': '18',
#    'bikes': '0',
#    'nearbyStations': '26',
#    'status': 'CLS'},
#   {'id': '27',
#    'type': 'BIKE',
#    'latitude': '41.396897',
#    'longitude': '2.164373',
#    'streetName': 'Provença',
#    'streetNumber': '322',
#    'altitude': '49',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '27',
#    'status': 'CLS'},
#   {'id': '28',
#    'type': 'BIKE',
#    'latitude': '41.405422',
#    'longitude': '2.17064',
#    'streetName': 'Sardenya',
#    'streetNumber': '362',
#    'altitude': '45',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '28',
#    'status': 'CLS'},
#   {'id': '29',
#    'type': 'BIKE',
#    'latitude': '41.401132',
#    'longitude': '2.170028',
#    'streetName': 'Provença',
#    'streetNumber': '388',
#    'altitude': '50',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '29',
#    'status': 'CLS'},
#   {'id': '30',
#    'type': 'BIKE',
#    'latitude': '41.402046',
#    'longitude': '2.182286',
#    'streetName': 'Diagonal',
#    'streetNumber': '231',
#    'altitude': '28',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '30',
#    'status': 'CLS'},
#   {'id': '31',
#    'type': 'BIKE',
#    'latitude': '41.37481',
#    'longitude': '2.18895',
#    'streetName': 'Plaça del Mar',
#    'streetNumber': '72',
#    'altitude': '1',
#    'slots': '18',
#    'bikes': '0',
#    'nearbyStations': '31',
#    'status': 'CLS'},
#   {'id': '32',
#    'type': 'BIKE',
#    'latitude': '41.373698',
#    'longitude': '2.188927',
#    'streetName': 'Plaça del Mar',
#    'streetNumber': '1',
#    'altitude': '1',
#    'slots': '26',
#    'bikes': '1',
#    'nearbyStations': '32',
#    'status': 'CLS'},
#   {'id': '33',
#    'type': 'BIKE',
#    'latitude': '41.376862',
#    'longitude': '2.190773',
#    'streetName': 'Pontevedra ',
#    'streetNumber': '58B',
#    'altitude': '1',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '33',
#    'status': 'CLS'},
#   {'id': '34',
#    'type': 'BIKE',
#    'latitude': '41.387074',
#    'longitude': '2.175247',
#    'streetName': 'Sant Pere Més Alt',
#    'streetNumber': '4',
#    'altitude': '16',
#    'slots': '19',
#    'bikes': '0',
#    'nearbyStations': '34',
#    'status': 'CLS'},
#   {'id': '35',
#    'type': 'BIKE',
#    'latitude': '41.413592',
#    'longitude': '2.221153',
#    'streetName': 'Sant Ramon de Penyafort',
#    'streetNumber': '1',
#    'altitude': '1',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '35',
#    'status': 'CLS'},
#   {'id': '36',
#    'type': 'BIKE',
#    'latitude': '41.385151',
#    'longitude': '2.176804',
#    'streetName': 'Catedral',
#    'streetNumber': '6',
#    'altitude': '16',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '36',
#    'status': 'CLS'},
#   {'id': '37',
#    'type': 'BIKE',
#    'latitude': '41.381226',
#    'longitude': '2.181888',
#    'streetName': 'Pl. Antonio López',
#    'streetNumber': '',
#    'altitude': '5',
#    'slots': '22',
#    'bikes': '0',
#    'nearbyStations': '37',
#    'status': 'CLS'},
#   {'id': '39',
#    'type': 'BIKE',
#    'latitude': '41.381046',
#    'longitude': '2.186576',
#    'streetName': 'Pl. Pau Vila',
#    'streetNumber': '',
#    'altitude': '1',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '39',
#    'status': 'CLS'},
#   {'id': '40',
#    'type': 'BIKE',
#    'latitude': '41.382335',
#    'longitude': '2.187093',
#    'streetName': 'Doctor Aiguader',
#    'streetNumber': '2',
#    'altitude': '1',
#    'slots': '17',
#    'bikes': '0',
#    'nearbyStations': '40',
#    'status': 'CLS'},
#   {'id': '41',
#    'type': 'BIKE',
#    'latitude': '41.379326',
#    'longitude': '2.189906',
#    'streetName': 'Pl. Poeta Boscà/Atlàntida',
#    'streetNumber': '',
#    'altitude': '1',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '41',
#    'status': 'CLS'},
#   {'id': '42',
#    'type': 'BIKE',
#    'latitude': '41.404511',
#    'longitude': '2.189881',
#    'streetName': 'Ciutat de Granada',
#    'streetNumber': '168',
#    'altitude': '18',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '42',
#    'status': 'CLS'},
#   {'id': '43',
#    'type': 'BIKE',
#    'latitude': '41.40541',
#    'longitude': '2.18712',
#    'streetName': 'Av Meridiana',
#    'streetNumber': '80',
#    'altitude': '18',
#    'slots': '1',
#    'bikes': '0',
#    'nearbyStations': '43',
#    'status': 'CLS'},
#   {'id': '44',
#    'type': 'BIKE',
#    'latitude': '41.402285',
#    'longitude': '2.187111',
#    'streetName': 'Av Meridiana',
#    'streetNumber': '66',
#    'altitude': '18',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '44',
#    'status': 'CLS'},
#   {'id': '45',
#    'type': 'BIKE',
#    'latitude': '41.391429',
#    'longitude': '2.189312',
#    'streetName': 'Sardenya',
#    'streetNumber': '66',
#    'altitude': '18',
#    'slots': '18',
#    'bikes': '0',
#    'nearbyStations': '45',
#    'status': 'CLS'},
#   {'id': '46',
#    'type': 'BIKE',
#    'latitude': '41.388359',
#    'longitude': '2.193004',
#    'streetName': 'Ramon trias Fargas',
#    'streetNumber': '19',
#    'altitude': '1',
#    'slots': '29',
#    'bikes': '0',
#    'nearbyStations': '46',
#    'status': 'CLS'},
#   {'id': '47',
#    'type': 'BIKE',
#    'latitude': '41.389831',
#    'longitude': '2.191147',
#    'streetName': 'Ramon Trias Fargas',
#    'streetNumber': '23',
#    'altitude': '1',
#    'slots': '36',
#    'bikes': '0',
#    'nearbyStations': '47',
#    'status': 'CLS'},
#   {'id': '48',
#    'type': 'BIKE',
#    'latitude': '41.396085',
#    'longitude': '2.187073',
#    'streetName': 'Meridiana',
#    'streetNumber': '40',
#    'altitude': '18',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '48',
#    'status': 'CLS'},
#   {'id': '49',
#    'type': 'BIKE',
#    'latitude': '41.39106',
#    'longitude': '2.196457',
#    'streetName': 'Rosa Sensat en front',
#    'streetNumber': '20',
#    'altitude': '1',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '49',
#    'status': 'CLS'},
#   {'id': '50',
#    'type': 'BIKE',
#    'latitude': '41.375',
#    'longitude': '2.17035',
#    'streetName': 'Av. Paral.lel',
#    'streetNumber': '54',
#    'altitude': '1',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '50',
#    'status': 'CLS'},
#   {'id': '51',
#    'type': 'BIKE',
#    'latitude': '41.384054',
#    'longitude': '2.169019',
#    'streetName': 'Pl. Vicenç Martorell',
#    'streetNumber': '',
#    'altitude': '32',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '51',
#    'status': 'CLS'},
#   {'id': '52',
#    'type': 'BIKE',
#    'latitude': '41.381766',
#    'longitude': '2.17738',
#    'streetName': 'Plaça de Sant Miquel',
#    'streetNumber': '1',
#    'altitude': '5',
#    'slots': '2',
#    'bikes': '0',
#    'nearbyStations': '52',
#    'status': 'CLS'},
#   {'id': '53',
#    'type': 'BIKE',
#    'latitude': '41.385227',
#    'longitude': '2.173878',
#    'streetName': 'Pl. Carles Pi i Sunyer',
#    'streetNumber': '',
#    'altitude': '32',
#    'slots': '24',
#    'bikes': '0',
#    'nearbyStations': '53',
#    'status': 'CLS'},
#   {'id': '54',
#    'type': 'BIKE',
#    'latitude': '41.377635',
#    'longitude': '2.170586',
#    'streetName': 'Sant Oleguer',
#    'streetNumber': '2',
#    'altitude': '24',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '54',
#    'status': 'CLS'},
#   {'id': '55',
#    'type': 'BIKE',
#    'latitude': '41.381154',
#    'longitude': '2.173497',
#    'streetName': 'La Rambla',
#    'streetNumber': '80',
#    'altitude': '24',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '55',
#    'status': 'CLS'},
#   {'id': '56',
#    'type': 'BIKE',
#    'latitude': '41.377011',
#    'longitude': '2.175834',
#    'streetName': 'Portal de Santa Madrona',
#    'streetNumber': '2',
#    'altitude': '5',
#    'slots': '24',
#    'bikes': '0',
#    'nearbyStations': '56',
#    'status': 'CLS'},
#   {'id': '57',
#    'type': 'BIKE',
#    'latitude': '41.376758',
#    'longitude': '2.177093',
#    'streetName': 'La Rambla',
#    'streetNumber': '2',
#    'altitude': '5',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '57',
#    'status': 'CLS'},
#   {'id': '58',
#    'type': 'BIKE',
#    'latitude': '41.382822',
#    'longitude': '2.167154',
#    'streetName': 'Plaça dels Àngels',
#    'streetNumber': '1',
#    'altitude': '24',
#    'slots': '20',
#    'bikes': '1',
#    'nearbyStations': '58',
#    'status': 'CLS'},
#   {'id': '59',
#    'type': 'BIKE',
#    'latitude': '41.382781',
#    'longitude': '2.167203',
#    'streetName': 'Plaça dels Àngels',
#    'streetNumber': '2',
#    'altitude': '24',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '59',
#    'status': 'CLS'},
#   {'id': '60',
#    'type': 'BIKE',
#    'latitude': '41.390349',
#    'longitude': '2.16424',
#    'streetName': 'Rambla Catalunya ',
#    'streetNumber': '47',
#    'altitude': '41',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '60',
#    'status': 'CLS'},
#   {'id': '61',
#    'type': 'BIKE',
#    'latitude': '41.390143',
#    'longitude': '2.164946',
#    'streetName': 'Rambla Catalunya',
#    'streetNumber': '42',
#    'altitude': '41',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '61',
#    'status': 'CLS'},
#   {'id': '62',
#    'type': 'BIKE',
#    'latitude': '41.387142',
#    'longitude': '2.168858',
#    'streetName': 'Pl. Catalunya ',
#    'streetNumber': '5',
#    'altitude': '32',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '62',
#    'status': 'CLS'},
#   {'id': '63',
#    'type': 'BIKE',
#    'latitude': '41.386439',
#    'longitude': '2.169417',
#    'streetName': 'Pl. Catalunya',
#    'streetNumber': '7',
#    'altitude': '32',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '63',
#    'status': 'CLS'},
#   {'id': '64',
#    'type': 'BIKE',
#    'latitude': '41.387469',
#    'longitude': '2.169048',
#    'streetName': 'Pl. Catalunya',
#    'streetNumber': '',
#    'altitude': '32',
#    'slots': '20',
#    'bikes': '1',
#    'nearbyStations': '64',
#    'status': 'CLS'},
#   {'id': '65',
#    'type': 'BIKE',
#    'latitude': '41.387678',
#    'longitude': '2.169587',
#    'streetName': 'Pl. Catalunya',
#    'streetNumber': '',
#    'altitude': '32',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '65',
#    'status': 'CLS'},
#   {'id': '66',
#    'type': 'BIKE',
#    'latitude': '41.389097',
#    'longitude': '2.167933',
#    'streetName': 'Gran Via',
#    'streetNumber': '609',
#    'altitude': '32',
#    'slots': '15',
#    'bikes': '0',
#    'nearbyStations': '66',
#    'status': 'CLS'},
#   {'id': '67',
#    'type': 'BIKE',
#    'latitude': '41.385012',
#    'longitude': '2.145843',
#    'streetName': 'Rocafort',
#    'streetNumber': '214',
#    'altitude': '51',
#    'slots': '23',
#    'bikes': '0',
#    'nearbyStations': '67',
#    'status': 'CLS'},
#   {'id': '68',
#    'type': 'BIKE',
#    'latitude': '41.395364',
#    'longitude': '2.157356',
#    'streetName': 'Rambla Catalunya',
#    'streetNumber': '133',
#    'altitude': '59',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '68',
#    'status': 'CLS'},
#   {'id': '69',
#    'type': 'BIKE',
#    'latitude': '41.386814',
#    'longitude': '2.195689',
#    'streetName': 'Avda. Litoral',
#    'streetNumber': '',
#    'altitude': '1',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '69',
#    'status': 'CLS'},
#   {'id': '70',
#    'type': 'BIKE',
#    'latitude': '41.380347',
#    'longitude': '2.160695',
#    'streetName': 'Comte Urgell',
#    'streetNumber': '23',
#    'altitude': '35',
#    'slots': '19',
#    'bikes': '0',
#    'nearbyStations': '70',
#    'status': 'CLS'},
#   {'id': '71',
#    'type': 'BIKE',
#    'latitude': '41.381931',
#    'longitude': '2.162969',
#    'streetName': 'Floridablanca',
#    'streetNumber': '145',
#    'altitude': '35',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '71',
#    'status': 'CLS'},
#   {'id': '72',
#    'type': 'BIKE',
#    'latitude': '41.392716',
#    'longitude': '2.158811',
#    'streetName': 'Provença',
#    'streetNumber': '215',
#    'altitude': '55',
#    'slots': '24',
#    'bikes': '0',
#    'nearbyStations': '72',
#    'status': 'CLS'},
#   {'id': '73',
#    'type': 'BIKE',
#    'latitude': '41.392278',
#    'longitude': '2.156183',
#    'streetName': 'Enric Granados',
#    'streetNumber': '93',
#    'altitude': '59',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '73',
#    'status': 'CLS'},
#   {'id': '74',
#    'type': 'BIKE',
#    'latitude': '41.390062',
#    'longitude': '2.143272',
#    'streetName': 'Josep Tarradellas',
#    'streetNumber': '133',
#    'altitude': '51',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '74',
#    'status': 'CLS'},
#   {'id': '75',
#    'type': 'BIKE',
#    'latitude': '41.385081',
#    'longitude': '2.142868',
#    'streetName': 'Josep Tarradellas',
#    'streetNumber': '58',
#    'altitude': '51',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '75',
#    'status': 'CLS'},
#   {'id': '76',
#    'type': 'BIKE',
#    'latitude': '41.391751',
#    'longitude': '2.153123',
#    'streetName': 'Còrsega',
#    'streetNumber': '216',
#    'altitude': '45',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '76',
#    'status': 'CLS'},
#   {'id': '77',
#    'type': 'BIKE',
#    'latitude': '41.39005',
#    'longitude': '2.152905',
#    'streetName': 'Casanova',
#    'streetNumber': '141',
#    'altitude': '45',
#    'slots': '0',
#    'bikes': '0',
#    'nearbyStations': '77',
#    'status': 'CLS'},
#   {'id': '78',
#    'type': 'BIKE',
#    'latitude': '41.385598',
#    'longitude': '2.16338',
#    'streetName': 'Pl. Universitat',
#    'streetNumber': '',
#    'altitude': '41',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '78',
#    'status': 'CLS'},
#   {'id': '79',
#    'type': 'BIKE',
#    'latitude': '41.38547',
#    'longitude': '2.16333',
#    'streetName': 'Pl. Universitat',
#    'streetNumber': '',
#    'altitude': '41',
#    'slots': '22',
#    'bikes': '0',
#    'nearbyStations': '79',
#    'status': 'CLS'},
#   {'id': '80',
#    'type': 'BIKE',
#    'latitude': '41.389687',
#    'longitude': '2.159999',
#    'streetName': 'Enric Granados',
#    'streetNumber': '35',
#    'altitude': '41',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '80',
#    'status': 'CLS'},
#   {'id': '81',
#    'type': 'BIKE',
#    'latitude': '41.378915',
#    'longitude': '2.149174',
#    'streetName': 'Vilamarí davant',
#    'streetNumber': '61',
#    'altitude': '44',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '81',
#    'status': 'CLS'},
#   {'id': '82',
#    'type': 'BIKE',
#    'latitude': '41.379016',
#    'longitude': '2.153799',
#    'streetName': 'Rocafort',
#    'streetNumber': '72',
#    'altitude': '40',
#    'slots': '32',
#    'bikes': '0',
#    'nearbyStations': '82',
#    'status': 'CLS'},
#   {'id': '83',
#    'type': 'BIKE',
#    'latitude': '41.384075',
#    'longitude': '2.153654',
#    'streetName': 'Comte Borrell',
#    'streetNumber': '177',
#    'altitude': '45',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '83',
#    'status': 'CLS'},
#   {'id': '84',
#    'type': 'BIKE',
#    'latitude': '41.383047',
#    'longitude': '2.157033',
#    'streetName': "Comte d'Urgell",
#    'streetNumber': '75 B',
#    'altitude': '35',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '84',
#    'status': 'CLS'},
#   {'id': '85',
#    'type': 'BIKE',
#    'latitude': '41.375076',
#    'longitude': '2.159046',
#    'streetName': 'Paral·lel',
#    'streetNumber': '146',
#    'altitude': '35',
#    'slots': '16',
#    'bikes': '6',
#    'nearbyStations': '85',
#    'status': 'CLS'},
#   {'id': '86',
#    'type': 'BIKE',
#    'latitude': '41.37544',
#    'longitude': '2.163',
#    'streetName': 'Viladomat',
#    'streetNumber': '2',
#    'altitude': '35',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '86',
#    'status': 'CLS'},
#   {'id': '87',
#    'type': 'BIKE',
#    'latitude': '41.383156',
#    'longitude': '2.148506',
#    'streetName': 'Mallorca',
#    'streetNumber': '41',
#    'altitude': '44',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '87',
#    'status': 'CLS'},
#   {'id': '88',
#    'type': 'BIKE',
#    'latitude': '41.393547',
#    'longitude': '2.150764',
#    'streetName': 'Londres',
#    'streetNumber': '101',
#    'altitude': '59',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '88',
#    'status': 'CLS'},
#   {'id': '89',
#    'type': 'BIKE',
#    'latitude': '41.38824',
#    'longitude': '2.150252',
#    'streetName': 'Rosselló',
#    'streetNumber': '101',
#    'altitude': '45',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '89',
#    'status': 'CLS'},
#   {'id': '90',
#    'type': 'BIKE',
#    'latitude': '41.38834',
#    'longitude': '2.150825',
#    'streetName': 'Rosselló',
#    'streetNumber': '108',
#    'altitude': '45',
#    'slots': '18',
#    'bikes': '0',
#    'nearbyStations': '90',
#    'status': 'CLS'},
#   {'id': '91',
#    'type': 'BIKE',
#    'latitude': '41.380452',
#    'longitude': '2.158403',
#    'streetName': 'Comte Borrell',
#    'streetNumber': '119',
#    'altitude': '35',
#    'slots': '30',
#    'bikes': '0',
#    'nearbyStations': '91',
#    'status': 'CLS'},
#   {'id': '92',
#    'type': 'BIKE',
#    'latitude': '41.39386',
#    'longitude': '2.160237',
#    'streetName': 'Provença',
#    'streetNumber': '241',
#    'altitude': '50',
#    'slots': '18',
#    'bikes': '0',
#    'nearbyStations': '92',
#    'status': 'CLS'},
#   {'id': '93',
#    'type': 'BIKE',
#    'latitude': '41.375454',
#    'longitude': '2.149786',
#    'streetName': 'Gran Via',
#    'streetNumber': '375',
#    'altitude': '40',
#    'slots': '23',
#    'bikes': '0',
#    'nearbyStations': '93',
#    'status': 'CLS'},
#   {'id': '94',
#    'type': 'BIKE',
#    'latitude': '41.375619',
#    'longitude': '2.149889',
#    'streetName': 'Gran Via',
#    'streetNumber': '375',
#    'altitude': '40',
#    'slots': '24',
#    'bikes': '0',
#    'nearbyStations': '94',
#    'status': 'CLS'},
#   {'id': '95',
#    'type': 'BIKE',
#    'latitude': '41.376428',
#    'longitude': '2.147734',
#    'streetName': 'Tarragona',
#    'streetNumber': '103',
#    'altitude': '44',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '95',
#    'status': 'CLS'},
#   {'id': '96',
#    'type': 'BIKE',
#    'latitude': '41.374152',
#    'longitude': '2.148154',
#    'streetName': 'Gran Via',
#    'streetNumber': '361',
#    'altitude': '61',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '96',
#    'status': 'CLS'},
#   {'id': '97',
#    'type': 'BIKE',
#    'latitude': '41.378124',
#    'longitude': '2.145389',
#    'streetName': 'Tarragona',
#    'streetNumber': '141',
#    'altitude': '44',
#    'slots': '19',
#    'bikes': '2',
#    'nearbyStations': '97',
#    'status': 'CLS'},
#   {'id': '98',
#    'type': 'BIKE',
#    'latitude': '41.380499',
#    'longitude': '2.141153',
#    'streetName': 'Viriat',
#    'streetNumber': '45',
#    'altitude': '44',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '98',
#    'status': 'CLS'},
#   {'id': '99',
#    'type': 'BIKE',
#    'latitude': '41.380632',
#    'longitude': '2.141548',
#    'streetName': 'Viriat',
#    'streetNumber': '53',
#    'altitude': '44',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '99',
#    'status': 'CLS'},
#   {'id': '100',
#    'type': 'BIKE',
#    'latitude': '41.379135',
#    'longitude': '2.14409',
#    'streetName': 'Tarragona',
#    'streetNumber': '159',
#    'altitude': '44',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '100',
#    'status': 'CLS'},
#   {'id': '101',
#    'type': 'BIKE',
#    'latitude': '41.392463',
#    'longitude': '2.143182',
#    'streetName': 'Av. Diagonal',
#    'streetNumber': '602',
#    'altitude': '69',
#    'slots': '0',
#    'bikes': '0',
#    'nearbyStations': '101',
#    'status': 'CLS'},
#   {'id': '102',
#    'type': 'BIKE',
#    'latitude': '41.39218',
#    'longitude': '2.14213',
#    'streetName': 'Av. Diagonal',
#    'streetNumber': '612',
#    'altitude': '69',
#    'slots': '24',
#    'bikes': '0',
#    'nearbyStations': '102',
#    'status': 'CLS'},
#   {'id': '103',
#    'type': 'BIKE',
#    'latitude': '41.409856',
#    'longitude': '2.188217',
#    'streetName': 'Aragó',
#    'streetNumber': '629',
#    'altitude': '17',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '103',
#    'status': 'CLS'},
#   {'id': '104',
#    'type': 'BIKE',
#    'latitude': '41.410821',
#    'longitude': '2.187365',
#    'streetName': 'C/València',
#    'streetNumber': '621',
#    'altitude': '17',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '104',
#    'status': 'CLS'},
#   {'id': '105',
#    'type': 'BIKE',
#    'latitude': '41.389197',
#    'longitude': '2.173555',
#    'streetName': 'PL. Urquinaona',
#    'streetNumber': '9',
#    'altitude': '32',
#    'slots': '18',
#    'bikes': '0',
#    'nearbyStations': '105',
#    'status': 'CLS'},
#   {'id': '106',
#    'type': 'BIKE',
#    'latitude': '41.405587',
#    'longitude': '2.162317',
#    'streetName': 'Pl. Joanic',
#    'streetNumber': 's/n',
#    'altitude': '59',
#    'slots': '19',
#    'bikes': '0',
#    'nearbyStations': '106',
#    'status': 'CLS'},
#   {'id': '107',
#    'type': 'BIKE',
#    'latitude': '41.398373',
#    'longitude': '2.153154',
#    'streetName': 'Travessera de Gracia',
#    'streetNumber': '92',
#    'altitude': '59',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '107',
#    'status': 'CLS'},
#   {'id': '108',
#    'type': 'BIKE',
#    'latitude': '41.402314',
#    'longitude': '2.164961',
#    'streetName': 'Indústria',
#    'streetNumber': '10',
#    'altitude': '59',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '108',
#    'status': 'CLS'},
#   {'id': '109',
#    'type': 'BIKE',
#    'latitude': '41.390981',
#    'longitude': '2.14737',
#    'streetName': 'C/ Londres',
#    'streetNumber': '53',
#    'altitude': '51',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '109',
#    'status': 'CLS'},
#   {'id': '110',
#    'type': 'BIKE',
#    'latitude': '41.385377',
#    'longitude': '2.154878',
#    'streetName': 'Avda. Roma',
#    'streetNumber': '136',
#    'altitude': '43',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '110',
#    'status': 'CLS'},
#   {'id': '111',
#    'type': 'BIKE',
#    'latitude': '41.381231',
#    'longitude': '2.152755',
#    'streetName': 'Calabria',
#    'streetNumber': '137',
#    'altitude': '41',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '111',
#    'status': 'CLS'},
#   {'id': '112',
#    'type': 'BIKE',
#    'latitude': '41.377644',
#    'longitude': '2.15725',
#    'streetName': 'Floridablanca',
#    'streetNumber': '49',
#    'altitude': '40',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '112',
#    'status': 'CLS'},
#   {'id': '113',
#    'type': 'BIKE',
#    'latitude': '41.377464',
#    'longitude': '2.164725',
#    'streetName': 'Sant Pau',
#    'streetNumber': '51',
#    'altitude': '30',
#    'slots': '25',
#    'bikes': '2',
#    'nearbyStations': '113',
#    'status': 'CLS'},
#   {'id': '114',
#    'type': 'BIKE',
#    'latitude': '41.376801',
#    'longitude': '2.173039',
#    'streetName': 'Pl. Jean Genet',
#    'streetNumber': '1',
#    'altitude': '24',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '114',
#    'status': 'CLS'},
#   {'id': '115',
#    'type': 'BIKE',
#    'latitude': '41.38377',
#    'longitude': '2.18424',
#    'streetName': "Marqués d'Argentera",
#    'streetNumber': '3',
#    'altitude': '1',
#    'slots': '18',
#    'bikes': '3',
#    'nearbyStations': '115',
#    'status': 'CLS'},
#   {'id': '116',
#    'type': 'BIKE',
#    'latitude': '41.383718',
#    'longitude': '2.191414',
#    'streetName': 'Salvat Papasseit',
#    'streetNumber': '72',
#    'altitude': '11',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '116',
#    'status': 'CLS'},
#   {'id': '117',
#    'type': 'BIKE',
#    'latitude': '41.390666',
#    'longitude': '2.197024',
#    'streetName': 'Rosa Sensat',
#    'streetNumber': '12',
#    'altitude': '1',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '117',
#    'status': 'CLS'},
#   {'id': '118',
#    'type': 'BIKE',
#    'latitude': '41.392212',
#    'longitude': '2.187847',
#    'streetName': 'Sardenya',
#    'streetNumber': '3',
#    'altitude': '18',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '118',
#    'status': 'CLS'},
#   {'id': '119',
#    'type': 'BIKE',
#    'latitude': '41.396684',
#    'longitude': '2.182447',
#    'streetName': 'Sardenya',
#    'streetNumber': '178',
#    'altitude': '21',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '119',
#    'status': 'CLS'},
#   {'id': '120',
#    'type': 'BIKE',
#    'latitude': '41.404666',
#    'longitude': '2.176515',
#    'streetName': 'Lepant',
#    'streetNumber': '278',
#    'altitude': '28',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '120',
#    'status': 'CLS'},
#   {'id': '121',
#    'type': 'BIKE',
#    'latitude': '41.406293',
#    'longitude': '2.178689',
#    'streetName': 'Castillejos',
#    'streetNumber': '258',
#    'altitude': '28',
#    'slots': '19',
#    'bikes': '0',
#    'nearbyStations': '121',
#    'status': 'CLS'},
#   {'id': '122',
#    'type': 'BIKE',
#    'latitude': '41.405435',
#    'longitude': '2.16624',
#    'streetName': 'Nàpols',
#    'streetNumber': '344',
#    'altitude': '59',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '122',
#    'status': 'CLS'},
#   {'id': '123',
#    'type': 'BIKE',
#    'latitude': '41.398013',
#    'longitude': '2.166978',
#    'streetName': 'Girona',
#    'streetNumber': '142',
#    'altitude': '45',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '123',
#    'status': 'CLS'},
#   {'id': '124',
#    'type': 'BIKE',
#    'latitude': '41.370297',
#    'longitude': '2.187808',
#    'streetName': 'Passeig Joan de Borbó',
#    'streetNumber': 's/n',
#    'altitude': '5',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '124',
#    'status': 'CLS'},
#   {'id': '125',
#    'type': 'BIKE',
#    'latitude': '41.384426',
#    'longitude': '2.195595',
#    'streetName': 'Passeig Maritim',
#    'streetNumber': '31',
#    'altitude': '1',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '125',
#    'status': 'CLS'},
#   {'id': '126',
#    'type': 'BIKE',
#    'latitude': '41.380778',
#    'longitude': '2.182581',
#    'streetName': 'Passeig de Colom',
#    'streetNumber': '',
#    'altitude': '5',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '126',
#    'status': 'CLS'},
#   {'id': '127',
#    'type': 'BIKE',
#    'latitude': '41.412322',
#    'longitude': '2.19142',
#    'streetName': 'Aragó',
#    'streetNumber': '661',
#    'altitude': '17',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '127',
#    'status': 'CLS'},
#   {'id': '128',
#    'type': 'BIKE',
#    'latitude': '41.415581',
#    'longitude': '2.19581',
#    'streetName': 'Rambla Guipúscoa',
#    'streetNumber': '43',
#    'altitude': '13',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '128',
#    'status': 'CLS'},
#   {'id': '129',
#    'type': 'BIKE',
#    'latitude': '41.377068',
#    'longitude': '2.161269',
#    'streetName': 'Manso',
#    'streetNumber': '46',
#    'altitude': '35',
#    'slots': '20',
#    'bikes': '7',
#    'nearbyStations': '129',
#    'status': 'CLS'},
#   {'id': '130',
#    'type': 'BIKE',
#    'latitude': '41.419905',
#    'longitude': '2.201573',
#    'streetName': 'Rambla Guipúscoa',
#    'streetNumber': '103',
#    'altitude': '9',
#    'slots': '24',
#    'bikes': '0',
#    'nearbyStations': '130',
#    'status': 'CLS'},
#   {'id': '131',
#    'type': 'BIKE',
#    'latitude': '41.422808',
#    'longitude': '2.206036',
#    'streetName': 'Rambla Guipúscoa',
#    'streetNumber': '158',
#    'altitude': '9',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '131',
#    'status': 'CLS'},
#   {'id': '132',
#    'type': 'BIKE',
#    'latitude': '41.408439',
#    'longitude': '2.192173',
#    'streetName': 'Pl. Valentí Amirall',
#    'streetNumber': '',
#    'altitude': '13',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '132',
#    'status': 'CLS'},
#   {'id': '133',
#    'type': 'BIKE',
#    'latitude': '41.407307',
#    'longitude': '2.192804',
#    'streetName': 'Gran Vía',
#    'streetNumber': '902',
#    'altitude': '16',
#    'slots': '17',
#    'bikes': '0',
#    'nearbyStations': '133',
#    'status': 'CLS'},
#   {'id': '134',
#    'type': 'BIKE',
#    'latitude': '41.411433',
#    'longitude': '2.198735',
#    'streetName': 'Bac de Roda',
#    'streetNumber': '157',
#    'altitude': '10',
#    'slots': '20',
#    'bikes': '0',
#    'nearbyStations': '134',
#    'status': 'CLS'},
#   {'id': '135',
#    'type': 'BIKE',
#    'latitude': '41.411908',
#    'longitude': '2.197936',
#    'streetName': 'Gran Vía',
#    'streetNumber': '981',
#    'altitude': '13',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '135',
#    'status': 'CLS'},
#   {'id': '136',
#    'type': 'BIKE',
#    'latitude': '41.414226',
#    'longitude': '2.201734',
#    'streetName': 'Gran Vía',
#    'streetNumber': '1062',
#    'altitude': '9',
#    'slots': '4',
#    'bikes': '22',
#    'nearbyStations': '136',
#    'status': 'CLS'},
#   {'id': '137',
#    'type': 'BIKE',
#    'latitude': '41.414758',
#    'longitude': '2.201538',
#    'streetName': 'Gran Vía, 1041/ Selva de Mar',
#    'streetNumber': '1041',
#    'altitude': '9',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '137',
#    'status': 'CLS'},
#   {'id': '138',
#    'type': 'BIKE',
#    'latitude': '41.416966',
#    'longitude': '2.205397',
#    'streetName': 'Gran Vía',
#    'streetNumber': '1118',
#    'altitude': '9',
#    'slots': '24',
#    'bikes': '0',
#    'nearbyStations': '138',
#    'status': 'CLS'},
#   {'id': '139',
#    'type': 'BIKE',
#    'latitude': '41.418035',
#    'longitude': '2.206023',
#    'streetName': 'Gran Vía',
#    'streetNumber': '1131',
#    'altitude': '9',
#    'slots': '0',
#    'bikes': '26',
#    'nearbyStations': '139',
#    'status': 'CLS'},
#   {'id': '140',
#    'type': 'BIKE',
#    'latitude': '41.38063',
#    'longitude': '2.15614',
#    'streetName': 'Viladomat',
#    'streetNumber': '122',
#    'altitude': '41',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '140',
#    'status': 'CLS'},
#   {'id': '141',
#    'type': 'BIKE',
#    'latitude': '41.40902',
#    'longitude': '2.194896',
#    'streetName': 'Gran Via ',
#    'streetNumber': '940',
#    'altitude': '13',
#    'slots': '29',
#    'bikes': '0',
#    'nearbyStations': '141',
#    'status': 'CLS'},
#   {'id': '142',
#    'type': 'BIKE',
#    'latitude': '41.400503',
#    'longitude': '2.192511',
#    'streetName': 'Sancho de Ávila',
#    'streetNumber': '104',
#    'altitude': '16',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '142',
#    'status': 'CLS'},
#   {'id': '143',
#    'type': 'BIKE',
#    'latitude': '41.40325',
#    'longitude': '2.19606',
#    'streetName': 'Sancho de Ávila',
#    'streetNumber': '170',
#    'altitude': '16',
#    'slots': '23',
#    'bikes': '0',
#    'nearbyStations': '143',
#    'status': 'CLS'},
#   {'id': '144',
#    'type': 'BIKE',
#    'latitude': '41.40562',
#    'longitude': '2.19764',
#    'streetName': 'Castella',
#    'streetNumber': '28',
#    'altitude': '16',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '144',
#    'status': 'CLS'},
#   {'id': '145',
#    'type': 'BIKE',
#    'latitude': '41.40982',
#    'longitude': '2.202904',
#    'streetName': 'Pere IV',
#    'streetNumber': '301',
#    'altitude': '9',
#    'slots': '25',
#    'bikes': '0',
#    'nearbyStations': '145',
#    'status': 'CLS'},
#   {'id': '146',
#    'type': 'BIKE',
#    'latitude': '41.415191',
#    'longitude': '2.207111',
#    'streetName': 'Pere IV',
#    'streetNumber': '449',
#    'altitude': '9',
#    'slots': '15',
#    'bikes': '0',
#    'nearbyStations': '146',
#    'status': 'CLS'},
#   {'id': '147',
#    'type': 'BIKE',
#    'latitude': '41.416018',
#    'longitude': '2.212658',
#    'streetName': 'Rambla Prim',
#    'streetNumber': '79',
#    'altitude': '5',
#    'slots': '25',
#    'bikes': '0',
#    'nearbyStations': '147',
#    'status': 'CLS'},
#   {'id': '148',
#    'type': 'BIKE',
#    'latitude': '41.378486',
#    'longitude': '2.163404',
#    'streetName': 'Ronda Sant Pau',
#    'streetNumber': '79',
#    'altitude': '79',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '148',
#    'status': 'CLS'},
#   {'id': '149',
#    'type': 'BIKE',
#    'latitude': '41.395905',
#    'longitude': '2.192958',
#    'streetName': 'Pujades',
#    'streetNumber': '57B',
#    'altitude': '11',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '149',
#    'status': 'CLS'},
#   {'id': '150',
#    'type': 'BIKE',
#    'latitude': '41.406549',
#    'longitude': '2.203112',
#    'streetName': 'Espronceda',
#    'streetNumber': '124',
#    'altitude': '10',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '150',
#    'status': 'CLS'},
#   {'id': '151',
#    'type': 'BIKE',
#    'latitude': '41.40065',
#    'longitude': '2.19719',
#    'streetName': 'Pallars',
#    'streetNumber': '462',
#    'altitude': '6',
#    'slots': '24',
#    'bikes': '0',
#    'nearbyStations': '151',
#    'status': 'CLS'},
#   {'id': '152',
#    'type': 'BIKE',
#    'latitude': '41.39925',
#    'longitude': '2.197421',
#    'streetName': 'Pujades',
#    'streetNumber': '121',
#    'altitude': '11',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '152',
#    'status': 'CLS'},
#   {'id': '153',
#    'type': 'BIKE',
#    'latitude': '41.401778',
#    'longitude': '2.200769',
#    'streetName': 'Pujades',
#    'streetNumber': '173',
#    'altitude': '10',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '153',
#    'status': 'CLS'},
#   {'id': '154',
#    'type': 'BIKE',
#    'latitude': '41.402454',
#    'longitude': '2.201656',
#    'streetName': 'Pujades',
#    'streetNumber': '191',
#    'altitude': '10',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '154',
#    'status': 'CLS'},
#   {'id': '155',
#    'type': 'BIKE',
#    'latitude': '41.406977',
#    'longitude': '2.207602',
#    'streetName': 'Pujades',
#    'streetNumber': '311',
#    'altitude': '10',
#    'slots': '32',
#    'bikes': '0',
#    'nearbyStations': '155',
#    'status': 'CLS'},
#   {'id': '156',
#    'type': 'BIKE',
#    'latitude': '41.409017',
#    'longitude': '2.20881',
#    'streetName': 'Diagonal',
#    'streetNumber': '46',
#    'altitude': '5',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '156',
#    'status': 'CLS'},
#   {'id': '157',
#    'type': 'BIKE',
#    'latitude': '41.412947',
#    'longitude': '2.217819',
#    'streetName': 'C/ LLULL - RBLA. PRIM',
#    'streetNumber': '465',
#    'altitude': '0',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '157',
#    'status': 'CLS'},
#   {'id': '158',
#    'type': 'BIKE',
#    'latitude': '41.411741',
#    'longitude': '2.218546',
#    'streetName': 'Rambla de Prim',
#    'streetNumber': '19',
#    'altitude': '1',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '158',
#    'status': 'CLS'},
#   {'id': '159',
#    'type': 'BIKE',
#    'latitude': '41.410882',
#    'longitude': '2.216703',
#    'streetName': 'Avda. Diagonal',
#    'streetNumber': '26',
#    'altitude': '5',
#    'slots': '22',
#    'bikes': '0',
#    'nearbyStations': '159',
#    'status': 'CLS'},
#   {'id': '160',
#    'type': 'BIKE',
#    'latitude': '41.411026',
#    'longitude': '2.219377',
#    'streetName': "Avda. d'Eduard Maristany",
#    'streetNumber': '1',
#    'altitude': '1',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '160',
#    'status': 'CLS'},
#   {'id': '161',
#    'type': 'BIKE',
#    'latitude': '41.395009',
#    'longitude': '2.196308',
#    'streetName': 'Ramon Turro',
#    'streetNumber': '91',
#    'altitude': '11',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '161',
#    'status': 'CLS'},
#   {'id': '162',
#    'type': 'BIKE',
#    'latitude': '41.403908',
#    'longitude': '2.208436',
#    'streetName': 'Ramon Turro',
#    'streetNumber': '292',
#    'altitude': '0',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '162',
#    'status': 'CLS'},
#   {'id': '163',
#    'type': 'BIKE',
#    'latitude': '41.3942',
#    'longitude': '2.20077',
#    'streetName': 'Avda. Icaria',
#    'streetNumber': '202',
#    'altitude': '11',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '163',
#    'status': 'CLS'},
#   {'id': '164',
#    'type': 'BIKE',
#    'latitude': '41.411901',
#    'longitude': '2.177895',
#    'streetName': 'Independència',
#    'streetNumber': '379',
#    'altitude': '33',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '164',
#    'status': 'CLS'},
#   {'id': '165',
#    'type': 'BIKE',
#    'latitude': '41.399196',
#    'longitude': '2.204253',
#    'streetName': 'Carrer del Doctor Trueta',
#    'streetNumber': '221',
#    'altitude': '0',
#    'slots': '25',
#    'bikes': '0',
#    'nearbyStations': '165',
#    'status': 'CLS'},
#   {'id': '166',
#    'type': 'BIKE',
#    'latitude': '41.400533',
#    'longitude': '2.206539',
#    'streetName': 'Bilbao',
#    'streetNumber': '11',
#    'altitude': '10',
#    'slots': '24',
#    'bikes': '0',
#    'nearbyStations': '166',
#    'status': 'CLS'},
#   {'id': '167',
#    'type': 'BIKE',
#    'latitude': '41.402561',
#    'longitude': '2.210538',
#    'streetName': 'Bac de Roda',
#    'streetNumber': '11',
#    'altitude': '0',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '167',
#    'status': 'CLS'},
#   {'id': '168',
#    'type': 'BIKE',
#    'latitude': '41.405358',
#    'longitude': '2.213677',
#    'streetName': 'Selva de Mar',
#    'streetNumber': '0',
#    'altitude': '0',
#    'slots': '24',
#    'bikes': '0',
#    'nearbyStations': '168',
#    'status': 'CLS'},
#   {'id': '170',
#    'type': 'BIKE',
#    'latitude': '41.389732',
#    'longitude': '2.199934',
#    'streetName': 'Avda. Litoral',
#    'streetNumber': '40',
#    'altitude': '1',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '170',
#    'status': 'CLS'},
#   {'id': '171',
#    'type': 'BIKE',
#    'latitude': '41.391986',
#    'longitude': '2.203699',
#    'streetName': 'Passeig Marítim de la Nova Icària',
#    'streetNumber': '83',
#    'altitude': '0',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '171',
#    'status': 'CLS'},
#   {'id': '173',
#    'type': 'BIKE',
#    'latitude': '41.398027',
#    'longitude': '2.208982',
#    'streetName': 'Avda. Litoral',
#    'streetNumber': '84',
#    'altitude': '0',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '173',
#    'status': 'CLS'},
#   {'id': '174',
#    'type': 'BIKE',
#    'latitude': '41.40061',
#    'longitude': '2.210461',
#    'streetName': 'Passeig de Garcia Fària',
#    'streetNumber': '21',
#    'altitude': '0',
#    'slots': '25',
#    'bikes': '1',
#    'nearbyStations': '174',
#    'status': 'CLS'},
#   {'id': '175',
#    'type': 'BIKE',
#    'latitude': '41.40666',
#    'longitude': '2.20956',
#    'streetName': 'Llull / Provençals',
#    'streetNumber': '309',
#    'altitude': '10',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '175',
#    'status': 'CLS'},
#   {'id': '176',
#    'type': 'BIKE',
#    'latitude': '41.402541',
#    'longitude': '2.212641',
#    'streetName': 'Passeig de Garcia Fària',
#    'streetNumber': '37',
#    'altitude': '0',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '176',
#    'status': 'CLS'},
#   {'id': '177',
#    'type': 'BIKE',
#    'latitude': '41.411089',
#    'longitude': '2.181119',
#    'streetName': 'Rosselló',
#    'streetNumber': '557',
#    'altitude': '0',
#    'slots': '25',
#    'bikes': '0',
#    'nearbyStations': '177',
#    'status': 'CLS'},
#   {'id': '178',
#    'type': 'BIKE',
#    'latitude': '41.405389',
#    'longitude': '2.216212',
#    'streetName': 'Passeig de Garcia Fària',
#    'streetNumber': '85',
#    'altitude': '0',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '178',
#    'status': 'CLS'},
#   {'id': '179',
#    'type': 'BIKE',
#    'latitude': '41.363511',
#    'longitude': '2.13677',
#    'streetName': 'Pg. Zona Franca',
#    'streetNumber': '244',
#    'altitude': '48',
#    'slots': '19',
#    'bikes': '0',
#    'nearbyStations': '179',
#    'status': 'CLS'},
#   {'id': '180',
#    'type': 'BIKE',
#    'latitude': '41.36778',
#    'longitude': '2.13926',
#    'streetName': 'Gran Via',
#    'streetNumber': '181',
#    'altitude': '50',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '180',
#    'status': 'CLS'},
#   {'id': '181',
#    'type': 'BIKE',
#    'latitude': '41.36766',
#    'longitude': '2.13911',
#    'streetName': 'Gran Via',
#    'streetNumber': '180',
#    'altitude': '50',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '181',
#    'status': 'CLS'},
#   {'id': '182',
#    'type': 'BIKE',
#    'latitude': '41.371455',
#    'longitude': '2.143882',
#    'streetName': 'Gran Via',
#    'streetNumber': '273',
#    'altitude': '61',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '182',
#    'status': 'CLS'},
#   {'id': '183',
#    'type': 'BIKE',
#    'latitude': '41.372338',
#    'longitude': '2.141875',
#    'streetName': 'Gavà',
#    'streetNumber': '1',
#    'altitude': '61',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '183',
#    'status': 'CLS'},
#   {'id': '184',
#    'type': 'BIKE',
#    'latitude': '41.367504',
#    'longitude': '2.134088',
#    'streetName': 'Quetzal',
#    'streetNumber': '22',
#    'altitude': '50',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '184',
#    'status': 'CLS'},
#   {'id': '185',
#    'type': 'BIKE',
#    'latitude': '41.37046',
#    'longitude': '2.138994',
#    'streetName': 'Gavà',
#    'streetNumber': '81',
#    'altitude': '50',
#    'slots': '19',
#    'bikes': '0',
#    'nearbyStations': '185',
#    'status': 'CLS'},
#   {'id': '186',
#    'type': 'BIKE',
#    'latitude': '41.375571',
#    'longitude': '2.143812',
#    'streetName': 'Consell de Cent',
#    'streetNumber': '6',
#    'altitude': '44',
#    'slots': '15',
#    'bikes': '0',
#    'nearbyStations': '186',
#    'status': 'CLS'},
#   {'id': '187',
#    'type': 'BIKE',
#    'latitude': '41.376858',
#    'longitude': '2.169811',
#    'streetName': 'Carrer de Sant Pau',
#    'streetNumber': '89',
#    'altitude': '24',
#    'slots': '18',
#    'bikes': '0',
#    'nearbyStations': '187',
#    'status': 'CLS'},
#   {'id': '188',
#    'type': 'BIKE',
#    'latitude': '41.375802',
#    'longitude': '2.135973',
#    'streetName': 'Pl. Sants (Ps. S. Antoni)',
#    'streetNumber': '0',
#    'altitude': '45',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '188',
#    'status': 'CLS'},
#   {'id': '189',
#    'type': 'BIKE',
#    'latitude': '41.396918',
#    'longitude': '2.166163',
#    'streetName': 'Bruc',
#    'streetNumber': '130',
#    'altitude': '50',
#    'slots': '23',
#    'bikes': '0',
#    'nearbyStations': '189',
#    'status': 'CLS'},
#   {'id': '190',
#    'type': 'BIKE',
#    'latitude': '41.39606',
#    'longitude': '2.207803',
#    'streetName': 'Avinguda Litoral',
#    'streetNumber': '72',
#    'altitude': '0',
#    'slots': '32',
#    'bikes': '0',
#    'nearbyStations': '190',
#    'status': 'CLS'},
#   {'id': '191',
#    'type': 'BIKE',
#    'latitude': '41.382564',
#    'longitude': '2.149094',
#    'streetName': 'Rocafort',
#    'streetNumber': '167',
#    'altitude': '44',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '191',
#    'status': 'CLS'},
#   {'id': '192',
#    'type': 'BIKE',
#    'latitude': '41.378629',
#    'longitude': '2.133467',
#    'streetName': 'Joan Güell',
#    'streetNumber': '50',
#    'altitude': '40',
#    'slots': '7',
#    'bikes': '2',
#    'nearbyStations': '192',
#    'status': 'CLS'},
#   {'id': '193',
#    'type': 'BIKE',
#    'latitude': '41.381311',
#    'longitude': '2.128912',
#    'streetName': 'Figols',
#    'streetNumber': '1',
#    'altitude': '46',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '193',
#    'status': 'CLS'},
#   {'id': '194',
#    'type': 'BIKE',
#    'latitude': '41.381013',
#    'longitude': '2.132319',
#    'streetName': 'Joan Güell',
#    'streetNumber': '98',
#    'altitude': '40',
#    'slots': '25',
# ...
#    'slots': '30',
#    'bikes': '0',
#    'nearbyStations': '360',
#    'status': 'CLS'},
#   {'id': '361',
#    'type': 'BIKE',
#    'latitude': '41.376292',
#    'longitude': '2.178553',
#    'streetName': 'Passeig de Colom',
#    'streetNumber': '',
#    'altitude': '5',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '361',
#    'status': 'CLS'},
#   {'id': '362',
#    'type': 'BIKE',
#    'latitude': '41.397006',
#    'longitude': '2.17057',
#    'streetName': 'Bailén',
#    'streetNumber': '100',
#    'altitude': '42',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '362',
#    'status': 'CLS'},
#   {'id': '363',
#    'type': 'BIKE',
#    'latitude': '41.39076',
#    'longitude': '2.1744',
#    'streetName': 'Bruc',
#    'streetNumber': '20',
#    'altitude': '32',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '363',
#    'status': 'CLS'},
#   {'id': '364',
#    'type': 'BIKE',
#    'latitude': '41.39324',
#    'longitude': '2.16343',
#    'streetName': 'Passeig de Gràcia',
#    'streetNumber': '61',
#    'altitude': '50',
#    'slots': '32',
#    'bikes': '0',
#    'nearbyStations': '364',
#    'status': 'CLS'},
#   {'id': '365',
#    'type': 'BIKE',
#    'latitude': '41.387499',
#    'longitude': '2.14702',
#    'streetName': 'Viladomat',
#    'streetNumber': '244',
#    'altitude': '51',
#    'slots': '32',
#    'bikes': '0',
#    'nearbyStations': '365',
#    'status': 'CLS'},
#   {'id': '366',
#    'type': 'BIKE',
#    'latitude': '41.393037',
#    'longitude': '2.14358',
#    'streetName': 'Pau Casals',
#    'streetNumber': '1',
#    'altitude': '69',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '366',
#    'status': 'CLS'},
#   {'id': '367',
#    'type': 'BIKE',
#    'latitude': '41.385057',
#    'longitude': '2.137331',
#    'streetName': 'Sentmenat',
#    'streetNumber': '39',
#    'altitude': '57',
#    'slots': '29',
#    'bikes': '1',
#    'nearbyStations': '367',
#    'status': 'CLS'},
#   {'id': '368',
#    'type': 'BIKE',
#    'latitude': '41.396815',
#    'longitude': '2.175714',
#    'streetName': 'Diputació',
#    'streetNumber': '350',
#    'altitude': '21',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '368',
#    'status': 'CLS'},
#   {'id': '369',
#    'type': 'BIKE',
#    'latitude': '41.400168',
#    'longitude': '2.177948',
#    'streetName': 'Consell de Cent',
#    'streetNumber': '482',
#    'altitude': '28',
#    'slots': '25',
#    'bikes': '0',
#    'nearbyStations': '369',
#    'status': 'CLS'},
#   {'id': '370',
#    'type': 'BIKE',
#    'latitude': '41.403735',
#    'longitude': '2.172987',
#    'streetName': 'Sardenya',
#    'streetNumber': '234',
#    'altitude': '49',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '370',
#    'status': 'CLS'},
#   {'id': '371',
#    'type': 'BIKE',
#    'latitude': '41.404027',
#    'longitude': '2.181264',
#    'streetName': 'Carrer dels Enamorats',
#    'streetNumber': '49',
#    'altitude': '28',
#    'slots': '31',
#    'bikes': '0',
#    'nearbyStations': '371',
#    'status': 'CLS'},
#   {'id': '372',
#    'type': 'BIKE',
#    'latitude': '41.400167',
#    'longitude': '2.184362',
#    'streetName': 'Ribes',
#    'streetNumber': '77',
#    'altitude': '18',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '372',
#    'status': 'CLS'},
#   {'id': '373',
#    'type': 'BIKE',
#    'latitude': '41.375073',
#    'longitude': '2.161305',
#    'streetName': 'Av. Paral.lel',
#    'streetNumber': '132',
#    'altitude': '35',
#    'slots': '34',
#    'bikes': '0',
#    'nearbyStations': '373',
#    'status': 'CLS'},
#   {'id': '374',
#    'type': 'BIKE',
#    'latitude': '41.395',
#    'longitude': '2.16123',
#    'streetName': 'Passeig de Gràcia',
#    'streetNumber': '89',
#    'altitude': '50',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '374',
#    'status': 'CLS'},
#   {'id': '375',
#    'type': 'BIKE',
#    'latitude': '41.372154',
#    'longitude': '2.180701',
#    'streetName': 'World Trade Center',
#    'streetNumber': '',
#    'altitude': '1',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '375',
#    'status': 'CLS'},
#   {'id': '376',
#    'type': 'BIKE',
#    'latitude': '41.371663',
#    'longitude': '2.180302',
#    'streetName': 'World Trade Center',
#    'streetNumber': '',
#    'altitude': '1',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '376',
#    'status': 'CLS'},
#   {'id': '377',
#    'type': 'BIKE',
#    'latitude': '41.37747',
#    'longitude': '2.183737',
#    'streetName': 'Pl. Ictíneo',
#    'streetNumber': '',
#    'altitude': '1',
#    'slots': '30',
#    'bikes': '0',
#    'nearbyStations': '377',
#    'status': 'CLS'},
#   {'id': '378',
#    'type': 'BIKE',
#    'latitude': '41.378516',
#    'longitude': '2.176716',
#    'streetName': 'Pl.Joaquim Xira i Palau',
#    'streetNumber': '1',
#    'altitude': '5',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '378',
#    'status': 'CLS'},
#   {'id': '379',
#    'type': 'BIKE',
#    'latitude': '41.381709',
#    'longitude': '2.177308',
#    'streetName': 'Pl. Sant Miquel',
#    'streetNumber': '4',
#    'altitude': '5',
#    'slots': '18',
#    'bikes': '0',
#    'nearbyStations': '379',
#    'status': 'CLS'},
#   {'id': '380',
#    'type': 'BIKE',
#    'latitude': '41.385463',
#    'longitude': '2.174252',
#    'streetName': 'Duran i Bas',
#    'streetNumber': '2',
#    'altitude': '32',
#    'slots': '23',
#    'bikes': '0',
#    'nearbyStations': '380',
#    'status': 'CLS'},
#   {'id': '381',
#    'type': 'BIKE',
#    'latitude': '41.381686',
#    'longitude': '2.167816',
#    'streetName': 'Agustí Duran i Sanpere',
#    'streetNumber': '10',
#    'altitude': '24',
#    'slots': '31',
#    'bikes': '0',
#    'nearbyStations': '381',
#    'status': 'CLS'},
#   {'id': '382',
#    'type': 'BIKE',
#    'latitude': '41.403938',
#    'longitude': '2.204188',
#    'streetName': 'Lope de Vega',
#    'streetNumber': '79',
#    'altitude': '10',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '382',
#    'status': 'CLS'},
#   {'id': '384',
#    'type': 'BIKE',
#    'latitude': '41.380708',
#    'longitude': '2.146793',
#    'streetName': 'Vilamarí',
#    'streetNumber': '85',
#    'altitude': '44',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '384',
#    'status': 'CLS'},
#   {'id': '385',
#    'type': 'BIKE',
#    'latitude': '41.387978',
#    'longitude': '2.155266',
#    'streetName': 'Casanova',
#    'streetNumber': '119',
#    'altitude': '45',
#    'slots': '30',
#    'bikes': '0',
#    'nearbyStations': '385',
#    'status': 'CLS'},
#   {'id': '386',
#    'type': 'BIKE',
#    'latitude': '41.375086',
#    'longitude': '2.156848',
#    'streetName': 'Av.Paral.lel',
#    'streetNumber': '164',
#    'altitude': '40',
#    'slots': '23',
#    'bikes': '0',
#    'nearbyStations': '386',
#    'status': 'CLS'},
#   {'id': '387',
#    'type': 'BIKE',
#    'latitude': '41.395796',
#    'longitude': '2.178784',
#    'streetName': 'Nàpols',
#    'streetNumber': '125',
#    'altitude': '21',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '387',
#    'status': 'CLS'},
#   {'id': '388',
#    'type': 'BIKE',
#    'latitude': '41.380593',
#    'longitude': '2.167418',
#    'streetName': 'Riera Alta',
#    'streetNumber': '6',
#    'altitude': '24',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '388',
#    'status': 'CLS'},
#   {'id': '389',
#    'type': 'BIKE',
#    'latitude': '41.38739',
#    'longitude': '2.1875',
#    'streetName': 'Recinte Parc de la Ciutadella',
#    'streetNumber': '',
#    'altitude': '11',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '389',
#    'status': 'CLS'},
#   {'id': '390',
#    'type': 'BIKE',
#    'latitude': '41.386955',
#    'longitude': '2.18195',
#    'streetName': 'Comerç',
#    'streetNumber': '36',
#    'altitude': '16',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '390',
#    'status': 'CLS'},
#   {'id': '391',
#    'type': 'BIKE',
#    'latitude': '41.422873',
#    'longitude': '2.191204',
#    'streetName': 'Sagrera',
#    'streetNumber': '74',
#    'altitude': '18',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '391',
#    'status': 'CLS'},
#   {'id': '392',
#    'type': 'BIKE',
#    'latitude': '41.390595',
#    'longitude': '2.190681',
#    'streetName': 'Ramon Turró',
#    'streetNumber': '4',
#    'altitude': '11',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '392',
#    'status': 'CLS'},
#   {'id': '393',
#    'type': 'BIKE',
#    'latitude': '41.402177',
#    'longitude': '2.197653',
#    'streetName': 'Llacuna',
#    'streetNumber': '86',
#    'altitude': '16',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '393',
#    'status': 'CLS'},
#   {'id': '394',
#    'type': 'BIKE',
#    'latitude': '41.387151',
#    'longitude': '2.162838',
#    'streetName': 'Diputació',
#    'streetNumber': '226',
#    'altitude': '41',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '394',
#    'status': 'CLS'},
#   {'id': '395',
#    'type': 'BIKE',
#    'latitude': '41.386009',
#    'longitude': '2.170212',
#    'streetName': 'Pl. Catalunya',
#    'streetNumber': '22',
#    'altitude': '32',
#    'slots': '32',
#    'bikes': '0',
#    'nearbyStations': '395',
#    'status': 'CLS'},
#   {'id': '396',
#    'type': 'BIKE',
#    'latitude': '41.389028',
#    'longitude': '2.196844',
#    'streetName': 'Joan Miró',
#    'streetNumber': '2',
#    'altitude': '1',
#    'slots': '31',
#    'bikes': '0',
#    'nearbyStations': '396',
#    'status': 'CLS'},
#   {'id': '397',
#    'type': 'BIKE',
#    'latitude': '41.388894',
#    'longitude': '2.199334',
#    'streetName': 'Av. Del Litoral',
#    'streetNumber': '24',
#    'altitude': '1',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '397',
#    'status': 'CLS'},
#   {'id': '398',
#    'type': 'BIKE',
#    'latitude': '41.381011',
#    'longitude': '2.193502',
#    'streetName': 'Passeig Marítim de la Barceloneta',
#    'streetNumber': '',
#    'altitude': '0',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '398',
#    'status': 'CLS'},
#   {'id': '400',
#    'type': 'BIKE',
#    'latitude': '41.36958',
#    'longitude': '2.188017',
#    'streetName': 'Moll Oriental',
#    'streetNumber': '',
#    'altitude': '5',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '400',
#    'status': 'CLS'},
#   {'id': '401',
#    'type': 'BIKE',
#    'latitude': '41.381241',
#    'longitude': '2.181838',
#    'streetName': 'Pl. Antonio López (Via Laietana) annexa a la 37',
#    'streetNumber': '',
#    'altitude': '5',
#    'slots': '23',
#    'bikes': '0',
#    'nearbyStations': '401',
#    'status': 'CLS'},
#   {'id': '402',
#    'type': 'BIKE',
#    'latitude': '41.380705',
#    'longitude': '2.182415',
#    'streetName': 'Passeig de Colom',
#    'streetNumber': '',
#    'altitude': '5',
#    'slots': '25',
#    'bikes': '0',
#    'nearbyStations': '402',
#    'status': 'CLS'},
#   {'id': '404',
#    'type': 'BIKE',
#    'latitude': '41.365374',
#    'longitude': '2.133087',
#    'streetName': 'Juan Gris',
#    'streetNumber': '28',
#    'altitude': '16',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '404',
#    'status': 'CLS'},
#   {'id': '405',
#    'type': 'BIKE',
#    'latitude': '41.38551',
#    'longitude': '2.152',
#    'streetName': 'Comte Borrell',
#    'streetNumber': '198',
#    'altitude': '45',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '405',
#    'status': 'CLS'},
#   {'id': '406',
#    'type': 'BIKE',
#    'latitude': '41.386512',
#    'longitude': '2.164597',
#    'streetName': 'Gran Via de Les Corts Catalanes',
#    'streetNumber': '592',
#    'altitude': '41',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '406',
#    'status': 'CLS'},
#   {'id': '408',
#    'type': 'BIKE',
#    'latitude': '41.388988',
#    'longitude': '2.192283',
#    'streetName': 'Ramon Trias Fargas',
#    'streetNumber': '23',
#    'altitude': '1',
#    'slots': '36',
#    'bikes': '0',
#    'nearbyStations': '408',
#    'status': 'CLS'},
#   {'id': '409',
#    'type': 'BIKE',
#    'latitude': '41.392272',
#    'longitude': '2.192556',
#    'streetName': "Joan d'Àustria",
#    'streetNumber': '31 B',
#    'altitude': '11',
#    'slots': '18',
#    'bikes': '0',
#    'nearbyStations': '409',
#    'status': 'CLS'},
#   {'id': '410',
#    'type': 'BIKE',
#    'latitude': '41.376433',
#    'longitude': '2.17871',
#    'streetName': 'Passeig de Colom, s/n',
#    'streetNumber': '',
#    'altitude': '5',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '410',
#    'status': 'CLS'},
#   {'id': '411',
#    'type': 'BIKE',
#    'latitude': '41.389499',
#    'longitude': '2.165387',
#    'streetName': 'Rambla Catalunya (Diputació)',
#    'streetNumber': '31',
#    'altitude': '41',
#    'slots': '0',
#    'bikes': '0',
#    'nearbyStations': '411',
#    'status': 'CLS'},
#   {'id': '412',
#    'type': 'BIKE',
#    'latitude': '41.389012',
#    'longitude': '2.172667',
#    'streetName': 'Pl. Urquinaona',
#    'streetNumber': '3',
#    'altitude': '32',
#    'slots': '26',
#    'bikes': '0',
#    'nearbyStations': '412',
#    'status': 'CLS'},
#   {'id': '413',
#    'type': 'BIKE',
#    'latitude': '41.393512',
#    'longitude': '2.170718',
#    'streetName': 'Bruc',
#    'streetNumber': '66',
#    'altitude': '42',
#    'slots': '25',
#    'bikes': '2',
#    'nearbyStations': '413',
#    'status': 'CLS'},
#   {'id': '414',
#    'type': 'BIKE',
#    'latitude': '41.393744',
#    'longitude': '2.176451',
#    'streetName': 'Casp',
#    'streetNumber': '67',
#    'altitude': '21',
#    'slots': '33',
#    'bikes': '0',
#    'nearbyStations': '414',
#    'status': 'CLS'},
#   {'id': '415',
#    'type': 'BIKE',
#    'latitude': '41.379374',
#    'longitude': '2.168921',
#    'streetName': 'Rambla del Raval',
#    'streetNumber': '13',
#    'altitude': '24',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '415',
#    'status': 'CLS'},
#   {'id': '416',
#    'type': 'BIKE',
#    'latitude': '41.378134',
#    'longitude': '2.16965',
#    'streetName': 'Rambla del Raval',
#    'streetNumber': '20',
#    'altitude': '24',
#    'slots': '25',
#    'bikes': '0',
#    'nearbyStations': '416',
#    'status': 'CLS'},
#   {'id': '418',
#    'type': 'BIKE',
#    'latitude': '41.390943',
#    'longitude': '2.180251',
#    'streetName': 'Passeig de Lluís Companys ',
#    'streetNumber': '',
#    'altitude': '16',
#    'slots': '25',
#    'bikes': '1',
#    'nearbyStations': '418',
#    'status': 'CLS'},
#   {'id': '419',
#    'type': 'BIKE',
#    'latitude': '41.391299',
#    'longitude': '2.180828',
#    'streetName': 'Passeig de Lluís Companys',
#    'streetNumber': '',
#    'altitude': '16',
#    'slots': '31',
#    'bikes': '0',
#    'nearbyStations': '419',
#    'status': 'CLS'},
#   {'id': '420',
#    'type': 'BIKE',
#    'latitude': '41.374213',
#    'longitude': '2.148082',
#    'streetName': 'Gran Via',
#    'streetNumber': '361',
#    'altitude': '61',
#    'slots': '18',
#    'bikes': '6',
#    'nearbyStations': '420',
#    'status': 'CLS'},
#   {'id': '421',
#    'type': 'BIKE',
#    'latitude': '41.378031',
#    'longitude': '2.139124',
#    'streetName': 'Plaça de Joan Peiró',
#    'streetNumber': '',
#    'altitude': '45',
#    'slots': '31',
#    'bikes': '0',
#    'nearbyStations': '421',
#    'status': 'CLS'},
#   {'id': '423',
#    'type': 'BIKE',
#    'latitude': '41.420201',
#    'longitude': '2.189532',
#    'streetName': "Carrer d'Hondures",
#    'streetNumber': '32',
#    'altitude': '18',
#    'slots': '3',
#    'bikes': '23',
#    'nearbyStations': '423',
#    'status': 'CLS'},
#   {'id': '424',
#    'type': 'BIKE',
#    'latitude': '41.379632',
#    'longitude': '2.192662',
#    'streetName': 'Passeig Marítim de la Barceloneta, devant del 5-7',
#    'streetNumber': '5',
#    'altitude': '0',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '424',
#    'status': 'CLS'},
#   {'id': '425',
#    'type': 'BIKE',
#    'latitude': '41.37652',
#    'longitude': '2.1749',
#    'streetName': 'Carrer de Cervelló',
#    'streetNumber': '5',
#    'altitude': '24',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '425',
#    'status': 'CLS'},
#   {'id': '426',
#    'type': 'BIKE',
#    'latitude': '41.398305',
#    'longitude': '2.183023',
#    'streetName': 'Carrer de Ribes',
#    'streetNumber': '59',
#    'altitude': '21',
#    'slots': '31',
#    'bikes': '0',
#    'nearbyStations': '426',
#    'status': 'CLS'},
#   {'id': '427',
#    'type': 'BIKE',
#    'latitude': '41.375336',
#    'longitude': '2.168007',
#    'streetName': 'Carrer de Sant Pau',
#    'streetNumber': '119',
#    'altitude': '24',
#    'slots': '21',
#    'bikes': '0',
#    'nearbyStations': '427',
#    'status': 'CLS'},
#   {'id': '428',
#    'type': 'BIKE',
#    'latitude': '41.398389',
#    'longitude': '2.196261',
#    'streetName': 'Carrer Pujades',
#    'streetNumber': '103',
#    'altitude': '11',
#    'slots': '27',
#    'bikes': '0',
#    'nearbyStations': '428',
#    'status': 'CLS'}],
#  'updateTime': 1554191231}

# %%
data['stations'][2]['slots']
# Out:
# '27'
